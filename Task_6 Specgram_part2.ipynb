# %% [markdown]
# ## Import libraries

# %%
import cProfile
# %pylab inline
import numpy as np
# %matplotlib agg

# %% [markdown]
# # Task 6 Advanced specgram

# %% [markdown]
# ## Run assistive plot functions

# %%
import imageio
from IPython.display import Image

# %%
def my_plot(x, y, title, xlabel, ylabel, fig_x_size = 15, fig_y_size = 10, font_param = 20):
    plt.figure(figsize=(fig_x_size, fig_y_size))
    plt.plot(x, y, "g.--")    
    plt.title(title) #, fontsize = font_param * 1.3)
    plt.xlabel(xlabel, fontsize = font_param)
    plt.ylabel(ylabel, fontsize = font_param)
    plt.xticks(fontsize = font_param)
    plt.yticks(fontsize = font_param)

# %%
def my_imshow(x, y, z, w,
              title, 
              xlabel, 
              ylabel,
              grid_active = False, fig_x_size = 15, fig_y_size = 10, font_param = 20):
    
    plt.figure(figsize=(fig_x_size, fig_y_size))
    im = plt.imshow(z, aspect='auto', 
               origin='lower', 
               extent=[min(x)/2/pi, max(x)/2/pi, y[0], 2 * w[int(len(x)/2)-1]])
    cbar = plt.colorbar()
    cbar.ax.tick_params(labelsize=font_param)
    plt.title(title, fontsize = font_param * 1.3)
    plt.xlabel(xlabel, fontsize = font_param)
    plt.ylabel(ylabel, fontsize = font_param)
    plt.xticks(fontsize = font_param)
    plt.yticks(fontsize = font_param)
    plt.grid(grid_active)
    plt.ylim(0, 10)
    return im

# %% [markdown]
# ## Generate the signal
# * E.g., signal consits of wave packets of three harmonic signals

# %%
def form_signal(n_timestamps = 4096):
    t=np.linspace(-20*2*pi, 20*2*pi, n_timestamps)
    y=np.sin(t)*exp(-t**2/2/20**2)               #generate first  wave packets of harmonic signal
    y=y+np.sin(3*t)*exp(-(t-5*2*pi)**2/2/20**2)  #add      second wave packets of harmonic signal
    y=y+np.sin(4*t)*exp(-(t-5*2*pi)**2/2/20**2)  
    y=y+np.sin(5*t)*exp(-(t-10*2*pi)**2/2/10**2) #add      third  wave packets of harmonic signal
    return t, y

# %%
#t, y = form_signal()
#my_plot(t / 2 / pi, y, title = "Discretized signal plotting", xlabel = 't, cycles', ylabel = 'signal, arb.units')
#plt.show()

# %% [markdown]
# ## Amplitude-Frequency Power (AFP) characteristic
#
# * <b> AFP </b> provides us with information about <strong>amplitudes </strong> of separated <strong> harmonic </strong> signals (spectral analysis)
# * <b> AFP </b> does <strong>not </strong> give information about the frequency and amplitude depence <strong> on time </strong>.
#
# ### Explain, why the "hats" of signal and AFP may be sharp

# %%
# Fourier spectrum
#sp=fft.fft(y)
#w=fft.fftfreq(len(y), d=(t[1]-t[0])/2/pi)
# plot(w, abs(sp)**2)

#my_plot(w, abs(sp)**2, title = "Amplitude-Frequency Power (AFP) characteristic", xlabel = 'Frequency, arb. units', ylabel = 'Power spectrum, arb. units')
#plt.xlim(0, 6)
#plt.show()

# %% [markdown]
# **Explanations.** On Amplitude-Frequency Power (AFP) characteristic we can clearly see three harmonics of the signal with angular frequency w = 1; 3; 4; 5.
# It is sharp "hats" that we can see.

# %% [markdown]
# ## Applicate short-time Fourier transform (STFT)
# * <b> STFT </b> provides us with information about the frequency and amplitude depence <strong> on time </strong> (specgram).
# * vary $\operatorname{kappa} = \overline{0.1, \,10}$, write down results into gif (add in title of picture values of kappa), and explain, why specgram is different.

# %%
def window_function(t, window_position, window_width):
    return exp(- (t - window_position) ** 2 / 2 / window_width ** 2)


def get_specgram(window_width, t, y, nwindowsteps = 1000):
    t_window_positions=linspace(-20 * 2 * pi, 20 * 2 * pi, nwindowsteps)

    specgram = np.empty([len(t), len(t_window_positions)])

    for i,t_window_position in enumerate(t_window_positions):
        y_window = y * window_function(t, t_window_position, window_width)
        #plot(y_window)
        specgram[:,i]=abs(fft.fft(y_window))

    return specgram


def repeat_function(window_width, nwindowsteps = 1000, repetitions = 100):
    for _ in range(repetitions):
        get_specgram(window_width = window_width, 
                     nwindowsteps = nwindowsteps)

# %%
kappa = 1
window_width_given = kappa * 2 * pi
nwindowsteps_given = 4099 #1000

def plot_specfram(window_width_given, nwindowsteps_given, t, y, w):
    im = my_imshow(t, w, get_specgram(window_width = window_width_given, t=t, y=y,
                                 nwindowsteps = nwindowsteps_given), w, 
              title = "Specgram nwindowsteps_given = "+str(nwindowsteps_given), 
              xlabel = "t, cycles", 
              ylabel = "Frequency, arb. units")
    # clim(0,0.5)
    plt.ylim(0, 10)
    im = plt.savefig('Specgram nwindowsteps_given = '+str(nwindowsteps_given)+'.png')
    
#plot_specfram(window_width_given, nwindowsteps_given, t, w)

# %%
#Image(url='Specgram nwindowsteps_given = '+str(nwindowsteps_given)+'.png')

# %% [markdown]
# **Create gif**

# %%
# %matplotlib agg

# %%
#name = 'animation.gif'

#with imageio.get_writer(name, mode='I') as writer:
#    for theta in np.linspace(np.log(0.001), np.log(10), 100):
#        kappa = np.exp(theta)
#        window_width_given = kappa * 2 * pi
#        nwindowsteps_given = 1000
#        im = my_imshow(t, w, get_specgram(window_width = window_width_given, nwindowsteps = nwindowsteps_given), title = "Specgram, kappa="+str(float("{0:.2f}".format(kappa))), xlabel = "t, cycles", ylabel = "Frequency, arb. units")
#        im = plt.savefig('foo.png')
#        writer.append_data(imageio.imread('foo.png'))

# %%
#Image(url='animation.gif')

# %% [markdown]
# **Explanations.** At different values of the Kappa, we capture a different frequency window. That is, it is not a classical Fourier transform in which frequencies on an infinite range will be gathered. We first divide diapason on windows and then used the Fourier transform for each window. So we get different spectograms.

# %% [markdown]
# ## cProfile the code
#
# * Vary $\operatorname{n\_timestamps\_given} = \overline{4090, \, 5000}$, write down results in this markdown and explain why cProfiler gives different results. What is bottleneck in this program? How can you improve the program?

# %%
#n_timestamps_given = 4096

def compute_specg(n_timestamps_given):
    kappa = 1
    window_width_given = kappa * 2 * pi
    t, y = form_signal(n_timestamps = n_timestamps_given)

    sp=fft.fft(y)
    w=fft.fftfreq(len(y), d=(t[1]-t[0])/2/pi)

    plot_specfram(window_width_given, n_timestamps_given, t, y, w)

# %%
#compute_specg(n_timestamps_given)

# %%
#Image(url='Specgram nwindowsteps_given = '+str(n_timestamps_given)+'.png')

# %%
import time

# %%
time_set = []
n_timestamps_set = np.arange(4096, 4150) #,5101)

start_time = time.time()

for n_timestamps_given in n_timestamps_set:
    
    compute_specg(n_timestamps_given)
    time_set.append(time.time() - start_time)
# Out:
# /Users/Makbukuska/miniconda3/envs/base2/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys

# %%
plt.clf()
plt.cla()

plt.plot(time_set, n_timestamps_set)    
plt.title('computational time vs timestamps') #, fontsize = font_param * 1.3)
plt.xlabel('computational time', fontsize =15)
plt.ylabel('timestamps', fontsize =15)
im = plt.savefig('computational_time_vs_timestamps.png')

# %%
Image(url='computational_time_vs_timestamps.png')
# Out:
# <img src="computational_time_vs_timestamps.png"/>

# %%
# cProfile.run('fft.fftfreq(len(y),' + ',' + 'd='+str((t[1]-t[0])/2/pi)+')')

# %%
n_timestamps_given = 4099
kappa = 1
window_width_given = kappa * 2 * pi
t, y = form_signal(n_timestamps = n_timestamps_given)
w=fft.fftfreq(len(y), d=(t[1]-t[0])/2/pi)

# %%
cProfile.run('fft.fftfreq('+str(len(y))+', '+ str((t[1]-t[0])/2/pi)+')') #'compute_specg('+str(n_timestamps_given)+')')
# Out:
#          8 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 helper.py:126(fftfreq)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
cProfile.run('plot_specfram(window_width_given, n_timestamps_given, t, y, w)')
# Out:
# /Users/Makbukuska/miniconda3/envs/base2/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys
#          201194 function calls (197444 primitive calls) in 3.148 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        30    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(all)
#       201    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(amax)
#       199    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(amin)
#       394    0.001    0.000    0.015    0.000 <__array_function__ internals>:2(any)
#       164    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(around)
#        37    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_1d)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#       102    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(broadcast_arrays)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(can_cast)
#        31    0.000    0.000    0.008    0.000 <__array_function__ internals>:2(clip)
#       115    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(column_stack)
#       162    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(concatenate)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(cumsum)
#        35    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(diff)
#       564    0.001    0.000    0.005    0.000 <__array_function__ internals>:2(dot)
#        35    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(hstack)
#        10    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(isclose)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(linspace)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(meshgrid)
#        17    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(min_scalar_type)
#        65    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#        28    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(nonzero)
#        24    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ptp)
#        13    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#       164    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(round_)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(shape)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(unravel_index)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(vstack)
#       128    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         1    0.000    0.000    0.483    0.483 <ipython-input-4-60be2dfceb23>:1(my_imshow)
#      4099    0.312    0.000    0.312    0.000 <ipython-input-8-8a96427a713d>:1(window_function)
#         1    0.392    0.392    1.867    1.867 <ipython-input-8-8a96427a713d>:5(get_specgram)
#         1    0.020    0.020    3.147    3.147 <ipython-input-9-ba3c0e85c62f>:5(plot_specfram)
#         1    0.000    0.000    3.147    3.147 <string>:1(<module>)
#       378    0.000    0.000    0.001    0.000 <string>:1(__new__)
#         4    0.000    0.000    0.000    0.000 __init__.py:1310(debug)
#         1    0.000    0.000    0.000    0.000 __init__.py:1322(get_backend)
#         1    0.000    0.000    0.000    0.000 __init__.py:1342(is_interactive)
#       149    0.000    0.000    0.000    0.000 __init__.py:1373(is_math_text)
#       407    0.000    0.000    0.002    0.000 __init__.py:1382(_to_unmasked_float_array)
#        36    0.000    0.000    0.000    0.000 __init__.py:143(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:1568(isEnabledFor)
#         2    0.004    0.002    0.346    0.173 __init__.py:1598(inner)
#       101    0.000    0.000    0.000    0.000 __init__.py:1616(<lambda>)
#        12    0.000    0.000    0.000    0.000 __init__.py:163(connect)
#        30    0.000    0.000    0.000    0.000 __init__.py:1651(safe_first_element)
#         4    0.000    0.000    0.000    0.000 __init__.py:1667(sanitize_sequence)
#       275    0.005    0.000    0.007    0.000 __init__.py:1673(normalize_kwargs)
#       275    0.000    0.000    0.000    0.000 __init__.py:1760(<listcomp>)
#       275    0.000    0.000    0.000    0.000 __init__.py:1765(<listcomp>)
#         2    0.000    0.000    0.000    0.000 __init__.py:180(_remove_proxy)
#       218    0.000    0.000    0.000    0.000 __init__.py:1906(_str_equal)
#       180    0.000    0.000    0.000    0.000 __init__.py:1916(_str_lower_equal)
#        35    0.000    0.000    0.000    0.000 __init__.py:1947(method)
#      1244    0.002    0.000    0.004    0.000 __init__.py:2012(_setattr_cm)
#       622    0.000    0.000    0.001    0.000 __init__.py:2017(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:2030(_warn_external)
#        70    0.002    0.000    0.002    0.000 __init__.py:205(process)
#         2    0.000    0.000    0.000    0.000 __init__.py:2053(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:2065(add)
#         2    0.000    0.000    0.000    0.000 __init__.py:21(get_projection_class)
#      1694    0.001    0.000    0.002    0.000 __init__.py:2151(_check_in_list)
#         6    0.000    0.000    0.000    0.000 __init__.py:232(__init__)
#         1    0.000    0.000    0.002    0.002 __init__.py:388(to_filehandle)
#         2    0.000    0.000    0.002    0.001 __init__.py:444(open_file_cm)
#         2    0.000    0.000    0.000    0.000 __init__.py:48(get_projection_class)
#        25    0.000    0.000    0.000    0.000 __init__.py:646(__setitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(__init__)
#         7    0.000    0.000    0.000    0.000 __init__.py:690(push)
#         5    0.000    0.000    0.000    0.000 __init__.py:715(clear)
#         3    0.005    0.002    0.005    0.002 __init__.py:720(bubble)
#         5    0.000    0.000    0.000    0.000 __init__.py:76(__init__)
#         4    0.000    0.000    0.291    0.073 __init__.py:794(safe_masked_invalid)
#      7619    0.005    0.000    0.007    0.000 __init__.py:810(__getitem__)
#        10    0.000    0.000    0.000    0.000 __init__.py:85(__hash__)
#         2    0.000    0.000    0.000    0.000 __init__.py:913(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:914(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 __init__.py:916(__contains__)
#        49    0.000    0.000    0.000    0.000 __init__.py:919(clean)
#        49    0.000    0.000    0.000    0.000 __init__.py:922(<listcomp>)
#        45    0.000    0.000    0.001    0.000 __init__.py:968(get_siblings)
#        45    0.001    0.000    0.001    0.000 __init__.py:972(<listcomp>)
#      1491    0.001    0.000    0.008    0.000 _asarray.py:16(asarray)
#       525    0.000    0.000    0.001    0.000 _asarray.py:88(asanyarray)
#         1    0.000    0.000    0.000    0.000 _axes.py:153(set_title)
#         1    0.000    0.000    0.000    0.000 _axes.py:223(set_xlabel)
#         3    0.000    0.000    0.000    0.000 _axes.py:256(set_ylabel)
#         1    0.000    0.000    0.339    0.339 _axes.py:5491(imshow)
#         1    0.000    0.000    0.000    0.000 _axes.py:5689(_pcolorargs)
#         1    0.000    0.000    0.000    0.000 _axes.py:5713(<listcomp>)
#         1    0.000    0.000    0.003    0.003 _axes.py:5992(pcolormesh)
#         3    0.000    0.000    0.000    0.000 _base.py:1133(_set_title_offset_trans)
#         8    0.000    0.000    0.000    0.000 _base.py:1219(get_aspect)
#         2    0.000    0.000    0.000    0.000 _base.py:1222(set_aspect)
#         4    0.000    0.000    0.000    0.000 _base.py:130(__init__)
#         2    0.000    0.000    0.000    0.000 _base.py:1304(set_adjustable)
#         4    0.000    0.000    0.000    0.000 _base.py:1345(get_anchor)
#         2    0.000    0.000    0.000    0.000 _base.py:1358(set_anchor)
#         4    0.000    0.000    0.000    0.000 _base.py:1414(get_data_ratio)
#         4    0.000    0.000    0.000    0.000 _base.py:143(set_prop_cycle)
#         8    0.000    0.000    0.001    0.000 _base.py:1446(apply_aspect)
#         1    0.000    0.000    0.000    0.000 _base.py:1783(_sci)
#         1    0.000    0.000    0.000    0.000 _base.py:1798(_gci)
#         2    0.000    0.000    0.000    0.000 _base.py:1819(add_artist)
#         1    0.000    0.000    0.000    0.000 _base.py:1858(add_collection)
#         1    0.000    0.000    0.000    0.000 _base.py:1878(add_image)
#         3    0.000    0.000    0.000    0.000 _base.py:2061(update_datalim)
#        13    0.000    0.000    0.001    0.000 _base.py:2097(_process_unit_info)
#        26    0.000    0.000    0.001    0.000 _base.py:2100(_process_single_axis)
#         3    0.000    0.000    0.000    0.000 _base.py:2185(use_sticky_edges)
#         3    0.000    0.000    0.004    0.001 _base.py:2388(autoscale_view)
#         2    0.000    0.000    0.000    0.000 _base.py:2415(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _base.py:2416(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _base.py:2417(<listcomp>)
#         6    0.000    0.000    0.004    0.001 _base.py:2425(handle_single_axis)
#         2    0.000    0.000    0.000    0.000 _base.py:2432(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _base.py:2434(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _base.py:2453(<listcomp>)
#        12    0.000    0.000    0.000    0.000 _base.py:2500(_get_axis_list)
#         4    0.000    0.000    0.010    0.003 _base.py:2503(_update_title_position)
#         4    0.000    0.000    0.677    0.169 _base.py:2573(draw)
#         2    0.000    0.000    0.000    0.000 _base.py:2619(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _base.py:2683(set_frame_on)
#         2    0.000    0.000    0.000    0.000 _base.py:2708(set_axisbelow)
#         6    0.000    0.000    0.035    0.006 _base.py:2744(grid)
#         5    0.000    0.000    0.005    0.001 _base.py:2918(tick_params)
#         2    0.000    0.000    0.000    0.000 _base.py:3027(set_axis_on)
#         1    0.000    0.000    0.000    0.000 _base.py:3050(xaxis_inverted)
#         5    0.000    0.000    0.000    0.000 _base.py:3064(get_xbound)
#         1    0.000    0.000    0.001    0.001 _base.py:3080(set_xbound)
#        10    0.000    0.000    0.000    0.000 _base.py:3120(get_xlim)
#        24    0.000    0.000    0.001    0.000 _base.py:3143(_validate_converted_limits)
#         5    0.000    0.000    0.001    0.000 _base.py:3161(set_xlim)
#        15    0.000    0.000    0.000    0.000 _base.py:3288(get_xscale)
#         1    0.000    0.000    0.003    0.003 _base.py:3298(set_xscale)
#         1    0.000    0.000    0.002    0.002 _base.py:3332(get_xticks)
#         1    0.000    0.000    0.015    0.015 _base.py:3377(get_xticklabels)
#         1    0.000    0.000    0.000    0.000 _base.py:3449(yaxis_inverted)
#         5    0.000    0.000    0.000    0.000 _base.py:3463(get_ybound)
#         1    0.000    0.000    0.000    0.000 _base.py:3479(set_ybound)
#        12    0.000    0.000    0.000    0.000 _base.py:3519(get_ylim)
#         7    0.000    0.000    0.002    0.000 _base.py:3542(set_ylim)
#        17    0.000    0.000    0.000    0.000 _base.py:3670(get_yscale)
#         1    0.003    0.003    0.006    0.006 _base.py:3680(set_yscale)
#         1    0.000    0.000    0.001    0.001 _base.py:3713(get_yticks)
#         1    0.000    0.000    0.015    0.015 _base.py:3757(get_yticklabels)
#         3    0.000    0.000    0.000    0.000 _base.py:3915(set_navigate)
#         2    0.000    0.000    0.000    0.000 _base.py:3931(set_navigate_mode)
#         2    0.000    0.000    0.068    0.034 _base.py:421(__init__)
#        10    0.000    0.000    0.000    0.000 _base.py:4248(get_children)
#         1    0.000    0.000    0.000    0.000 _base.py:4477(get_shared_x_axes)
#         1    0.000    0.000    0.000    0.000 _base.py:4481(get_shared_y_axes)
#        12    0.000    0.000    0.000    0.000 _base.py:576(get_window_extent)
#         2    0.000    0.000    0.013    0.007 _base.py:594(_init_axis)
#         2    0.000    0.000    0.000    0.000 _base.py:604(set_figure)
#         2    0.000    0.000    0.000    0.000 _base.py:624(_set_lim_and_transforms)
#   211/115    0.000    0.000    0.001    0.000 _base.py:660(get_xaxis_transform)
#        23    0.000    0.000    0.001    0.000 _base.py:684(get_xaxis_text1_transform)
#        23    0.000    0.000    0.001    0.000 _base.py:710(get_xaxis_text2_transform)
#   310/170    0.003    0.000    0.004    0.000 _base.py:736(get_yaxis_transform)
#        34    0.000    0.000    0.002    0.000 _base.py:760(get_yaxis_text1_transform)
#        34    0.000    0.000    0.001    0.000 _base.py:786(get_yaxis_text2_transform)
#         6    0.000    0.000    0.003    0.000 _base.py:812(_update_transScale)
#         8    0.000    0.000    0.000    0.000 _base.py:822(get_position)
#         9    0.000    0.000    0.001    0.000 _base.py:871(_set_position)
#         2    0.000    0.000    0.000    0.000 _base.py:898(set_axes_locator)
#         8    0.000    0.000    0.000    0.000 _base.py:909(get_axes_locator)
#        10    0.000    0.000    0.000    0.000 _base.py:915(_set_artist_props)
#         2    0.000    0.000    0.000    0.000 _base.py:925(_gen_axes_patch)
#         2    0.000    0.000    0.002    0.001 _base.py:942(_gen_axes_spines)
#        10    0.000    0.000    0.002    0.000 _base.py:957(<genexpr>)
#         2    0.000    0.000    0.049    0.024 _base.py:960(cla)
#      4099    0.010    0.000    0.013    0.000 _float_utils.py:55(__downcast_float128_array)
#         3    0.000    0.000    0.000    0.000 _internal.py:908(__init__)
#         1    0.000    0.000    0.000    0.000 _layoutbox.py:655(nonetree)
#        24    0.000    0.000    0.000    0.000 _methods.py:228(_ptp)
#       153    0.000    0.000    0.047    0.000 _methods.py:28(_amax)
#        89    0.000    0.000    0.054    0.001 _methods.py:32(_amin)
#        28    0.000    0.000    0.000    0.000 _methods.py:36(_sum)
#        14    0.000    0.000    0.006    0.000 _methods.py:44(_any)
#        23    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#        62    0.000    0.000    0.001    0.000 _methods.py:63(_clip_dep_is_scalar_nan)
#        62    0.000    0.000    0.000    0.000 _methods.py:73(_clip_dep_is_byte_swapped)
#        31    0.006    0.000    0.006    0.000 _methods.py:78(_clip_dep_invoke_with_casting)
#        31    0.000    0.000    0.008    0.000 _methods.py:97(_clip)
#      4099    0.003    0.000    0.003    0.000 _numpy_fft.py:67(_unitary)
#      4099    0.011    0.000    1.076    0.000 _numpy_fft.py:74(fft)
#        14    0.000    0.000    0.000    0.000 _pylab_helpers.py:100(get_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:110(set_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:116(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:30(get_fig_manager)
#         5    0.000    0.000    0.000    0.000 _subplots.py:110(get_subplotspec)
#         1    0.000    0.000    0.000    0.000 _subplots.py:114(set_subplotspec)
#         3    0.000    0.000    0.002    0.001 _subplots.py:122(update_params)
#         2    0.000    0.000    0.069    0.035 _subplots.py:18(__init__)
#        29    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#        29    0.000    0.000    0.000    0.000 _ufunc_config.py:39(seterr)
#        13    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#        13    0.000    0.000    0.000    0.000 _ufunc_config.py:441(__enter__)
#        13    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#       560    0.000    0.000    0.001    0.000 abc.py:137(__instancecheck__)
#        44    0.000    0.000    0.000    0.000 abc.py:141(__subclasscheck__)
#         4    0.000    0.000    0.000    0.000 artist.py:1001(get_zorder)
#       129    0.000    0.000    0.000    0.000 artist.py:1005(set_zorder)
#       364    0.000    0.000    0.000    0.000 artist.py:1020(sticky_edges)
#        85    0.000    0.000    0.001    0.000 artist.py:1043(update_from)
#       275    0.001    0.000    0.014    0.000 artist.py:1064(set)
#         8    0.000    0.000    0.000    0.000 artist.py:1070(<lambda>)
#        10    0.000    0.000    0.000    0.000 artist.py:1171(mouseover)
#         2    0.000    0.000    0.000    0.000 artist.py:163(have_units)
#       461    0.000    0.000    0.002    0.000 artist.py:170(convert_xunits)
#       469    0.000    0.000    0.001    0.000 artist.py:182(convert_yunits)
#      3508    0.001    0.000    0.001    0.000 artist.py:194(axes)
#       461    0.000    0.000    0.000    0.000 artist.py:199(axes)
# 8153/6839    0.010    0.000    0.013    0.000 artist.py:219(stale)
#     334/2    0.002    0.000    0.680    0.340 artist.py:30(draw_wrapper)
#      1631    0.001    0.000    0.001    0.000 artist.py:338(pchanged)
#        10    0.000    0.000    0.000    0.000 artist.py:352(is_transform_set)
#       325    0.000    0.000    0.001    0.000 artist.py:360(set_transform)
#       256    0.000    0.000    0.000    0.000 artist.py:373(get_transform)
#       813    0.001    0.000    0.003    0.000 artist.py:49(_stale_axes_callback)
#         2    0.000    0.000    0.000    0.000 artist.py:541(get_url)
#         1    0.000    0.000    0.000    0.000 artist.py:545(set_url)
#       114    0.000    0.000    0.000    0.000 artist.py:555(get_gid)
#        16    0.000    0.000    0.000    0.000 artist.py:569(get_snap)
#        60    0.000    0.000    0.000    0.000 artist.py:608(get_sketch_params)
#       110    0.000    0.000    0.000    0.000 artist.py:666(get_path_effects)
#         5    0.000    0.000    0.000    0.000 artist.py:669(get_figure)
#       377    0.001    0.000    0.001    0.000 artist.py:673(set_figure)
#        10    0.000    0.000    0.000    0.000 artist.py:697(set_clip_box)
#        33    0.000    0.000    0.007    0.000 artist.py:709(set_clip_path)
#       378    0.004    0.000    0.006    0.000 artist.py:74(__init__)
#        55    0.000    0.000    0.000    0.000 artist.py:763(get_alpha)
#       734    0.000    0.000    0.000    0.000 artist.py:770(get_visible)
#      8175    0.001    0.000    0.001    0.000 artist.py:774(get_animated)
#         2    0.000    0.000    0.000    0.000 artist.py:797(get_clip_path)
#       114    0.000    0.000    0.000    0.000 artist.py:828(_set_gc_clip)
#       668    0.000    0.000    0.000    0.000 artist.py:838(get_rasterized)
#         1    0.000    0.000    0.000    0.000 artist.py:842(set_rasterized)
#       668    0.000    0.000    0.000    0.000 artist.py:858(get_agg_filter)
#        59    0.000    0.000    0.000    0.000 artist.py:893(set_alpha)
#       407    0.000    0.000    0.001    0.000 artist.py:905(set_visible)
#       603    0.003    0.000    0.015    0.000 artist.py:942(update)
#       205    0.000    0.000    0.001    0.000 artist.py:946(_update_property)
#       603    0.000    0.000    0.002    0.000 artist.py:974(<listcomp>)
#         2    0.000    0.000    0.000    0.000 artist.py:981(get_label)
#         4    0.000    0.000    0.000    0.000 artist.py:985(set_label)
#         8    0.000    0.000    0.000    0.000 axis.py:1026(_set_artist_props)
#        16    0.001    0.000    0.054    0.003 axis.py:1074(_update_ticks)
#        16    0.000    0.000    0.017    0.001 axis.py:1147(_get_tick_bboxes)
#        16    0.000    0.000    0.012    0.001 axis.py:1149(<listcomp>)
#        16    0.000    0.000    0.005    0.000 axis.py:1151(<listcomp>)
#         8    0.000    0.000    0.118    0.015 axis.py:1195(draw)
#         2    0.000    0.000    0.030    0.015 axis.py:1250(get_majorticklabels)
#         2    0.000    0.000    0.000    0.000 axis.py:1253(<listcomp>)
#         2    0.000    0.000    0.000    0.000 axis.py:1254(<listcomp>)
#         2    0.000    0.000    0.030    0.015 axis.py:1264(get_ticklabels)
#        20    0.000    0.000    0.036    0.002 axis.py:1322(get_majorticklocs)
#        16    0.000    0.000    0.017    0.001 axis.py:1326(get_minorticklocs)
#        16    0.000    0.000    0.000    0.000 axis.py:1340(<listcomp>)
#         2    0.000    0.000    0.004    0.002 axis.py:1344(get_ticklocs)
#        17    0.000    0.000    0.004    0.000 axis.py:1374(_copy_tick_props)
#        14    0.000    0.000    0.000    0.000 axis.py:1388(get_major_locator)
#        19    0.000    0.000    0.036    0.002 axis.py:1404(get_major_ticks)
#        17    0.000    0.000    0.000    0.000 axis.py:1418(get_minor_ticks)
#        12    0.000    0.000    0.035    0.003 axis.py:1432(grid)
#        12    0.000    0.000    0.000    0.000 axis.py:1462(<dictcomp>)
#        14    0.000    0.000    0.001    0.000 axis.py:1480(update_units)
#        24    0.000    0.000    0.000    0.000 axis.py:1502(_update_axisinfo)
#        18    0.000    0.000    0.000    0.000 axis.py:1536(have_units)
#        64    0.000    0.000    0.001    0.000 axis.py:1539(convert_units)
#        57    0.000    0.000    0.000    0.000 axis.py:154(<dictcomp>)
#        24    0.000    0.000    0.003    0.000 axis.py:1556(set_units)
#         4    0.000    0.000    0.000    0.000 axis.py:1582(set_label_text)
#        35    0.000    0.000    0.000    0.000 axis.py:1603(set_major_formatter)
#        34    0.000    0.000    0.000    0.000 axis.py:1619(set_minor_formatter)
#        36    0.000    0.000    0.001    0.000 axis.py:1635(set_major_locator)
#        35    0.000    0.000    0.000    0.000 axis.py:1653(set_minor_locator)
#         2    0.000    0.000    0.000    0.000 axis.py:1741(set_ticks)
#        12    0.000    0.000    0.000    0.000 axis.py:1818(_get_ticks_position)
#        36    0.000    0.000    0.000    0.000 axis.py:1834(<genexpr>)
#        12    0.000    0.000    0.000    0.000 axis.py:1855(get_label_position)
#       110    0.000    0.000    0.001    0.000 axis.py:1881(getter)
#        23    0.000    0.000    0.038    0.002 axis.py:1928(_get_tick)
#         2    0.000    0.000    0.000    0.000 axis.py:1935(_get_label)
#         2    0.000    0.000    0.000    0.000 axis.py:1953(_get_offset_text)
#        57    0.000    0.000    0.000    0.000 axis.py:198(_set_labelrotation)
#         4    0.000    0.000    0.010    0.002 axis.py:1985(_get_tick_boxes_siblings)
#         4    0.000    0.000    0.011    0.003 axis.py:2004(_update_label_position)
#         4    0.000    0.000    0.001    0.000 axis.py:2047(_update_offset_text_position)
#        12    0.000    0.000    0.000    0.000 axis.py:2140(get_ticks_position)
#         5    0.000    0.000    0.000    0.000 axis.py:2153(get_minpos)
#        57    0.000    0.000    0.000    0.000 axis.py:216(get_tick_padding)
#        10    0.000    0.000    0.015    0.002 axis.py:2179(get_tick_space)
#        34    0.000    0.000    0.060    0.002 axis.py:2217(_get_tick)
#         2    0.000    0.000    0.000    0.000 axis.py:2224(_get_label)
#         2    0.000    0.000    0.000    0.000 axis.py:2244(_get_offset_text)
#         1    0.000    0.000    0.000    0.000 axis.py:2260(set_label_position)
#         4    0.000    0.000    0.016    0.004 axis.py:2279(_get_tick_boxes_siblings)
#         4    0.000    0.000    0.018    0.005 axis.py:2298(_update_label_position)
#        12    0.000    0.000    0.005    0.000 axis.py:230(set_clip_path)
#         4    0.000    0.000    0.000    0.000 axis.py:2340(_update_offset_text_position)
#         1    0.000    0.000    0.000    0.000 axis.py:2351(set_offset_position)
#         1    0.000    0.000    0.002    0.002 axis.py:2387(set_ticks_position)
#         7    0.000    0.000    0.000    0.000 axis.py:2460(get_minpos)
#        18    0.000    0.000    0.029    0.002 axis.py:2486(get_tick_space)
#        88    0.000    0.000    0.000    0.000 axis.py:285(get_loc)
#        44    0.000    0.000    0.034    0.001 axis.py:289(draw)
#        88    0.000    0.000    0.001    0.000 axis.py:301(set_label1)
#        88    0.000    0.000    0.000    0.000 axis.py:314(set_label2)
#       285    0.000    0.000    0.001    0.000 axis.py:325(_set_artist_props)
#        55    0.001    0.000    0.016    0.000 axis.py:332(_apply_params)
#       275    0.000    0.000    0.000    0.000 axis.py:340(<genexpr>)
#        55    0.000    0.000    0.000    0.000 axis.py:359(<dictcomp>)
#        55    0.000    0.000    0.000    0.000 axis.py:370(<dictcomp>)
#        55    0.000    0.000    0.000    0.000 axis.py:381(<dictcomp>)
#        23    0.000    0.000    0.001    0.000 axis.py:405(_get_text1_transform)
#        23    0.000    0.000    0.001    0.000 axis.py:408(_get_text2_transform)
#        23    0.000    0.000    0.000    0.000 axis.py:411(apply_tickdir)
#        23    0.000    0.000    0.003    0.000 axis.py:425(_get_text1)
#        23    0.000    0.000    0.005    0.000 axis.py:442(_get_text2)
#        23    0.000    0.000    0.012    0.001 axis.py:458(_get_tick1line)
#        23    0.000    0.000    0.007    0.000 axis.py:469(_get_tick2line)
#        23    0.000    0.000    0.008    0.000 axis.py:484(_get_gridline)
#        59    0.000    0.000    0.001    0.000 axis.py:500(update_position)
#        34    0.000    0.000    0.003    0.000 axis.py:522(_get_text1_transform)
#        34    0.000    0.000    0.001    0.000 axis.py:525(_get_text2_transform)
#        34    0.000    0.000    0.000    0.000 axis.py:528(apply_tickdir)
#        34    0.000    0.000    0.011    0.000 axis.py:543(_get_text1)
#        34    0.000    0.000    0.005    0.000 axis.py:558(_get_text2)
#        57    0.002    0.000    0.097    0.002 axis.py:56(__init__)
#        34    0.000    0.000    0.012    0.000 axis.py:573(_get_tick1line)
#        34    0.000    0.000    0.010    0.000 axis.py:588(_get_tick2line)
#        34    0.000    0.000    0.018    0.001 axis.py:602(_get_gridline)
#        86    0.000    0.000    0.001    0.000 axis.py:617(update_position)
#      12/8    0.000    0.000    0.034    0.004 axis.py:658(__get__)
#         4    0.000    0.000    0.006    0.002 axis.py:715(__init__)
#        16    0.000    0.000    0.000    0.000 axis.py:759(get_remove_overlapping_locs)
#       118    0.000    0.000    0.003    0.000 axis.py:792(get_transform)
#        32    0.000    0.000    0.000    0.000 axis.py:795(get_scale)
#        34    0.000    0.000    0.009    0.000 axis.py:798(_set_scale)
#        12    0.000    0.000    0.000    0.000 axis.py:807(limit_range_for_scale)
#        24    0.000    0.000    0.009    0.000 axis.py:819(cla)
#        32    0.000    0.000    0.000    0.000 axis.py:842(reset_ticks)
#        23    0.000    0.000    0.042    0.002 axis.py:862(set_tick_params)
#        23    0.000    0.000    0.000    0.000 axis.py:900(_translate_tick_kw)
#         4    0.000    0.000    0.015    0.004 axis.py:945(set_clip_path)
#         2    0.000    0.000    0.000    0.000 axis.py:988(get_inverted)
#         1    0.000    0.000    0.000    0.000 backend_agg.py:102(_update_methods)
#        16    0.000    0.000    0.009    0.001 backend_agg.py:119(draw_path)
#        50    0.001    0.000    0.018    0.000 backend_agg.py:164(draw_text)
#        50    0.000    0.000    0.008    0.000 backend_agg.py:193(get_text_width_height_descent)
#        50    0.000    0.000    0.000    0.000 backend_agg.py:237(get_canvas_width_height)
#       100    0.000    0.000    0.004    0.000 backend_agg.py:241(_get_agg_font)
#        88    0.000    0.000    0.000    0.000 backend_agg.py:254(points_to_pixels)
#         1    0.000    0.000    0.001    0.001 backend_agg.py:267(clear)
#         6    0.000    0.000    0.000    0.000 backend_agg.py:270(option_image_nocomposite)
#         2    0.000    0.000    0.684    0.342 backend_agg.py:382(draw)
#         3    0.000    0.000    0.004    0.001 backend_agg.py:393(get_renderer)
#         1    0.000    0.000    0.461    0.461 backend_agg.py:450(print_png)
#       100    0.000    0.000    0.000    0.000 backend_agg.py:49(get_hinting_flag)
#         1    0.003    0.003    0.003    0.003 backend_agg.py:80(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1225(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1254(__init__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:150(__init__)
#       170    0.000    0.000    0.000    0.000 backend_bases.py:154(open_group)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1581(__init__)
#       170    0.000    0.000    0.000    0.000 backend_bases.py:161(close_group)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1633(_idle_draw_cntx)
#         4    0.000    0.000    0.000    0.000 backend_bases.py:1639(is_saving)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1656(draw_event)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1889(draw)
#         1    0.000    0.000    0.314    0.314 backend_bases.py:1892(draw_idle)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1939(_get_output_canvas)
#         1    0.000    0.000    0.463    0.463 backend_bases.py:1958(print_figure)
#         7    0.000    0.000    0.000    0.000 backend_bases.py:2141(mpl_connect)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2482(__init__)
#         3    0.000    0.000    0.000    0.000 backend_bases.py:2500(notify_axes_change)
#         1    0.000    0.000    0.001    0.001 backend_bases.py:3244(new_figure_manager)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3254(new_figure_manager_given_figure)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3262(draw_if_interactive)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:451(get_image_magnification)
#        50    0.000    0.000    0.000    0.000 backend_bases.py:635(flipy)
#       114    0.000    0.000    0.002    0.000 backend_bases.py:654(new_gc)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:683(start_rasterizing)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:690(stop_rasterizing)
#       114    0.001    0.000    0.002    0.000 backend_bases.py:718(__init__)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:759(restore)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:788(get_clip_path)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:798(get_dashes)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:840(get_snap)
#        68    0.000    0.000    0.000    0.000 backend_bases.py:851(set_alpha)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:868(set_antialiased)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:873(set_capstyle)
#         6    0.000    0.000    0.000    0.000 backend_bases.py:880(set_clip_rectangle)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:886(set_clip_path)
#        16    0.000    0.000    0.000    0.000 backend_bases.py:897(set_dashes)
#       178    0.000    0.000    0.000    0.000 backend_bases.py:918(set_foreground)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:938(set_joinstyle)
#        62    0.000    0.000    0.000    0.000 backend_bases.py:945(set_linewidth)
#        68    0.000    0.000    0.000    0.000 backend_bases.py:949(set_url)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:953(set_gid)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:957(set_snap)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:972(get_hatch)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:976(get_hatch_path)
#       114    0.004    0.000    0.004    0.000 backend_bases.py:983(get_hatch_color)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:991(get_hatch_linewidth)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:995(get_sketch_params)
#         5    0.000    0.000    0.000    0.000 cm.py:155(get_cmap)
#         2    0.000    0.000    0.000    0.000 cm.py:193(__init__)
#         3    0.001    0.000    0.032    0.011 cm.py:223(to_rgba)
#         1    0.000    0.000    0.000    0.000 cm.py:293(set_array)
#         3    0.000    0.000    0.000    0.000 cm.py:303(get_array)
#         1    0.000    0.000    0.000    0.000 cm.py:315(set_clim)
#         1    0.000    0.000    0.000    0.000 cm.py:345(set_cmap)
#         1    0.000    0.000    0.000    0.000 cm.py:357(set_norm)
#         3    0.000    0.000    0.047    0.016 cm.py:386(autoscale_None)
#         2    0.000    0.000    0.000    0.000 cm.py:403(check_update)
#         6    0.000    0.000    0.000    0.000 cm.py:413(changed)
#         2    0.000    0.000    0.000    0.000 collections.py:174(get_offset_transform)
#         1    0.000    0.000    0.000    0.000 collections.py:1910(__init__)
#         2    0.000    0.000    0.002    0.001 collections.py:2002(draw)
#         1    0.000    0.000    0.000    0.000 collections.py:335(set_pickradius)
#         1    0.000    0.000    0.000    0.000 collections.py:378(set_urls)
#         1    0.000    0.000    0.000    0.000 collections.py:390(set_hatch)
#         1    0.000    0.000    0.000    0.000 collections.py:455(set_offset_position)
#         1    0.000    0.000    0.000    0.000 collections.py:483(set_linewidth)
#         1    0.000    0.000    0.000    0.000 collections.py:505(set_linestyle)
#         2    0.000    0.000    0.000    0.000 collections.py:584(_bcast_lwls)
#         2    0.000    0.000    0.000    0.000 collections.py:617(<listcomp>)
#         1    0.000    0.000    0.000    0.000 collections.py:622(set_antialiased)
#         2    0.000    0.000    0.000    0.000 collections.py:651(_set_facecolor)
#         1    0.000    0.000    0.000    0.000 collections.py:664(set_facecolor)
#         2    0.000    0.000    0.000    0.000 collections.py:680(get_facecolor)
#         2    0.000    0.000    0.000    0.000 collections.py:683(get_edgecolor)
#         2    0.000    0.000    0.000    0.000 collections.py:689(_set_edgecolor)
#         1    0.000    0.000    0.000    0.000 collections.py:717(set_edgecolor)
#         1    0.000    0.000    0.000    0.000 collections.py:730(set_alpha)
#         2    0.000    0.000    0.000    0.000 collections.py:748(get_linewidth)
#         2    0.000    0.000    0.000    0.000 collections.py:754(update_scalarmappable)
#         1    0.000    0.000    0.000    0.000 collections.py:90(__init__)
#         2    0.000    0.000    0.000    0.000 colorbar.py:1006(_uniform_y)
#         1    0.000    0.000    0.002    0.002 colorbar.py:1070(_mesh)
#         1    0.000    0.000    0.023    0.023 colorbar.py:1155(__init__)
#         1    0.000    0.000    0.054    0.054 colorbar.py:1471(make_axes_gridspec)
#         1    0.000    0.000    0.024    0.024 colorbar.py:1626(colorbar_factory)
#         1    0.000    0.000    0.000    0.000 colorbar.py:228(__init__)
#         8    0.000    0.000    0.014    0.002 colorbar.py:240(tick_values)
#         1    0.000    0.000    0.023    0.023 colorbar.py:398(__init__)
#         2    0.000    0.000    0.000    0.000 colorbar.py:462(_extend_lower)
#         2    0.000    0.000    0.000    0.000 colorbar.py:466(_extend_upper)
#         1    0.000    0.000    0.000    0.000 colorbar.py:470(_patch_ax)
#         1    0.000    0.000    0.014    0.014 colorbar.py:476(draw_all)
#         1    0.000    0.000    0.002    0.002 colorbar.py:497(config_axis)
#         1    0.000    0.000    0.000    0.000 colorbar.py:511(_get_ticker_locator_formatter)
#         3    0.000    0.000    0.000    0.000 colorbar.py:563(_use_auto_colorbar_locator)
#         1    0.000    0.000    0.009    0.009 colorbar.py:573(_reset_locator_formatter_scale)
#         1    0.000    0.000    0.000    0.000 colorbar.py:593(update_ticks)
#         1    0.000    0.000    0.002    0.002 colorbar.py:695(_config_axes)
#         2    0.000    0.000    0.000    0.000 colorbar.py:729(_set_label)
#         1    0.000    0.000    0.000    0.000 colorbar.py:736(set_label)
#         1    0.000    0.000    0.000    0.000 colorbar.py:742(_outline)
#         1    0.000    0.000    0.008    0.008 colorbar.py:767(_add_solids)
#       2/1    0.000    0.000    0.001    0.001 colorbar.py:863(_process_values)
#         1    0.000    0.000    0.000    0.000 colorbar.py:948(_find_range)
#         1    0.000    0.000    0.000    0.000 colorbar.py:957(_central_N)
#         5    0.000    0.000    0.000    0.000 colors.py:1005(scaled)
#         4    0.000    0.000    0.000    0.000 colors.py:105(_sanitize_extrema)
#       388    0.000    0.000    0.002    0.000 colors.py:115(_is_nth_color)
#       388    0.001    0.000    0.003    0.000 colors.py:149(to_rgba)
#         4    0.000    0.000    0.000    0.000 colors.py:254(to_rgba_array)
#         3    0.007    0.002    0.031    0.010 colors.py:480(__call__)
#         2    0.000    0.000    0.000    0.000 colors.py:891(__init__)
#        17    0.000    0.000    0.006    0.000 colors.py:913(process_value)
#         3    0.003    0.001    0.009    0.003 colors.py:944(__call__)
#         4    0.000    0.000    0.002    0.000 colors.py:979(inverse)
#         8    0.000    0.000    0.047    0.006 colors.py:997(autoscale_None)
#       690    0.001    0.000    0.007    0.000 contextlib.py:107(__enter__)
#       690    0.001    0.000    0.003    0.000 contextlib.py:116(__exit__)
#       690    0.001    0.000    0.003    0.000 contextlib.py:237(helper)
#       690    0.002    0.000    0.003    0.000 contextlib.py:81(__init__)
#         3    0.000    0.000    0.000    0.000 copy.py:268(_reconstruct)
#         3    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         3    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
#         3    0.000    0.000    0.000    0.000 core.py:1005(__call__)
#        40    0.000    0.000    0.000    0.000 core.py:1278(_replace_dtype_fields_recursive)
#        40    0.000    0.000    0.000    0.000 core.py:1310(_replace_dtype_fields)
#        40    0.000    0.000    0.000    0.000 core.py:1324(make_mask_descr)
#       130    0.000    0.000    0.000    0.000 core.py:1357(getmask)
#         6    0.000    0.000    0.000    0.000 core.py:1419(getmaskarray)
#         7    0.000    0.000    0.005    0.001 core.py:1540(_shrink_mask)
#         3    0.000    0.000    0.000    0.000 core.py:1550(make_mask)
#         6    0.000    0.000    0.000    0.000 core.py:1639(make_mask_none)
#         3    0.000    0.000    0.000    0.000 core.py:1689(mask_or)
#         6    0.000    0.000    0.000    0.000 core.py:1813(_check_mask_axis)
#         8    0.000    0.000    0.000    0.000 core.py:210(_recursive_fill_value)
#         8    0.000    0.000    0.000    0.000 core.py:225(_get_dtype_of)
#         4    0.056    0.014    0.056    0.014 core.py:2331(masked_invalid)
#         2    0.000    0.000    0.000    0.000 core.py:235(default_fill_value)
#         6    0.000    0.000    0.000    0.000 core.py:2578(wrapped_method)
#        31    0.000    0.000    0.010    0.000 core.py:2773(__new__)
#         2    0.000    0.000    0.000    0.000 core.py:280(_scalar_fill_value)
#         6    0.000    0.000    0.000    0.000 core.py:290(_extremum_fill_value)
#        94    0.001    0.000    0.001    0.000 core.py:2903(_update_from)
#         6    0.000    0.000    0.000    0.000 core.py:292(_scalar_fill_value)
#        75    0.001    0.000    0.002    0.000 core.py:2929(__array_finalize__)
#         3    0.000    0.000    0.000    0.000 core.py:3022(__array_wrap__)
#         3    0.000    0.000    0.000    0.000 core.py:3040(<listcomp>)
#         3    0.000    0.000    0.000    0.000 core.py:305(minimum_fill_value)
#         5    0.000    0.000    0.000    0.000 core.py:3078(view)
#        30    0.000    0.000    0.000    0.000 core.py:3161(__getitem__)
#        16    0.000    0.000    0.000    0.000 core.py:3178(_scalar_heuristic)
#       176    0.000    0.000    0.000    0.000 core.py:3347(dtype)
#        44    0.000    0.000    0.000    0.000 core.py:3363(shape)
#         2    0.000    0.000    0.000    0.000 core.py:3367(shape)
#         8    0.000    0.000    0.000    0.000 core.py:3446(mask)
#         4    0.002    0.000    0.007    0.002 core.py:3541(shrink_mask)
#         3    0.000    0.000    0.000    0.000 core.py:356(maximum_fill_value)
#        79    0.000    0.000    0.000    0.000 core.py:3577(_get_data)
#         2    0.000    0.000    0.000    0.000 core.py:3607(fill_value)
#         9    0.000    0.000    0.000    0.000 core.py:3663(filled)
#         3    0.000    0.000    0.000    0.000 core.py:3960(_delegate_binop)
#         3    0.000    0.000    0.000    0.000 core.py:4098(__mul__)
#         2    0.000    0.000    0.000    0.000 core.py:439(_check_fill_value)
#         1    0.000    0.000    0.000    0.000 core.py:4483(ravel)
#         4    0.000    0.000    0.000    0.000 core.py:4537(reshape)
#         3    0.000    0.000    0.054    0.018 core.py:5604(min)
#         3    0.000    0.000    0.047    0.016 core.py:5734(max)
#         4    0.000    0.000    0.000    0.000 core.py:5879(<lambda>)
#        21    0.000    0.000    0.000    0.000 core.py:593(filled)
#         3    0.000    0.000    0.000    0.000 core.py:639(get_masked_subclass)
#        23    0.000    0.000    0.010    0.000 core.py:6415(array)
#         2    0.000    0.000    0.000    0.000 core.py:6432(is_masked)
#         3    0.000    0.000    0.000    0.000 core.py:653(<listcomp>)
#        27    0.000    0.000    0.000    0.000 core.py:666(getdata)
#         6    0.000    0.000    0.000    0.000 core.py:7778(asarray)
#         2    0.000    0.000    0.000    0.000 core.py:778(is_string_or_list_of_strings)
#         4    0.000    0.000    0.000    0.000 core.py:781(<genexpr>)
#        26    0.000    0.000    0.000    0.000 cycler.py:138(keys)
#        26    0.000    0.000    0.000    0.000 cycler.py:225(__iter__)
#       242    0.000    0.000    0.000    0.000 cycler.py:227(<genexpr>)
#        22    0.000    0.000    0.000    0.000 cycler.py:349(by_key)
#        44    0.000    0.000    0.000    0.000 cycler.py:371(<genexpr>)
#         1    0.000    0.000    0.000    0.000 decorators.py:41(wrapper)
#       2/1    0.000    0.000    0.339    0.339 deprecation.py:358(wrapper)
#         3    0.000    0.000    0.000    0.000 figure.py:100(_entry_from_axes)
#         3    0.000    0.000    0.000    0.000 figure.py:101(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 figure.py:1072(_make_key)
#         2    0.000    0.000    0.000    0.000 figure.py:1075(fixitems)
#         3    0.000    0.000    0.005    0.002 figure.py:108(bubble)
#         2    0.000    0.000    0.000    0.000 figure.py:1091(fixlist)
#         2    0.000    0.000    0.000    0.000 figure.py:1102(_process_projection_requirements)
#         2    0.000    0.000    0.000    0.000 figure.py:115(add)
#         2    0.000    0.000    0.070    0.035 figure.py:1261(add_subplot)
#         2    0.000    0.000    0.000    0.000 figure.py:1418(_add_axes_internal)
#        20    0.000    0.000    0.000    0.000 figure.py:145(current_key_axes)
#         7    0.000    0.000    0.000    0.000 figure.py:157(__call__)
#         2    0.000    0.000    0.000    0.000 figure.py:160(__contains__)
#         1    0.000    0.000    0.000    0.000 figure.py:1624(clf)
#         2    0.000    0.000    0.680    0.340 figure.py:1661(draw)
#         6    0.000    0.000    0.000    0.000 figure.py:1675(<genexpr>)
#         4    0.000    0.000    0.000    0.000 figure.py:1676(<lambda>)
#         4    0.000    0.000    0.000    0.000 figure.py:168(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:1882(_set_artist_props)
#        12    0.000    0.000    0.016    0.001 figure.py:1888(gca)
#         3    0.000    0.000    0.005    0.002 figure.py:1934(sca)
#         1    0.000    0.000    0.000    0.000 figure.py:1941(_gci)
#         7    0.000    0.000    0.000    0.000 figure.py:199(update)
#         1    0.000    0.000    0.000    0.000 figure.py:2034(add_axobserver)
#         1    0.000    0.000    0.463    0.463 figure.py:2038(savefig)
#         1    0.000    0.000    0.083    0.083 figure.py:2190(colorbar)
#         1    0.000    0.000    0.000    0.000 figure.py:2214(<dictcomp>)
#        42    0.000    0.000    0.000    0.000 figure.py:235(_update_this)
#         1    0.000    0.000    0.000    0.000 figure.py:275(__init__)
#         5    0.000    0.000    0.000    0.000 figure.py:452(_get_axes)
#       194    0.000    0.000    0.000    0.000 figure.py:462(_get_dpi)
#         2    0.000    0.000    0.001    0.000 figure.py:465(_set_dpi)
#         2    0.000    0.000    0.000    0.000 figure.py:482(get_tight_layout)
#         1    0.000    0.000    0.000    0.000 figure.py:486(set_tight_layout)
#       501    0.000    0.000    0.001    0.000 figure.py:49(_stale_figure_callback)
#         5    0.000    0.000    0.000    0.000 figure.py:504(get_constrained_layout)
#         1    0.000    0.000    0.000    0.000 figure.py:512(set_constrained_layout)
#         1    0.000    0.000    0.000    0.000 figure.py:543(set_constrained_layout_pads)
#         2    0.000    0.000    0.000    0.000 figure.py:652(get_children)
#         1    0.000    0.000    0.000    0.000 figure.py:70(__init__)
#         7    0.000    0.000    0.000    0.000 figure.py:74(as_list)
#         3    0.000    0.000    0.000    0.000 figure.py:779(set_canvas)
#         7    0.000    0.000    0.000    0.000 figure.py:78(<listcomp>)
#         7    0.000    0.000    0.000    0.000 figure.py:80(<listcomp>)
#         4    0.000    0.000    0.000    0.000 figure.py:82(get)
#         2    0.000    0.000    0.000    0.000 figure.py:875(set_size_inches)
#         6    0.000    0.000    0.000    0.000 figure.py:898(<genexpr>)
#         6    0.000    0.000    0.000    0.000 figure.py:915(get_size_inches)
#         1    0.000    0.000    0.000    0.000 figure.py:930(get_edgecolor)
#         1    0.000    0.000    0.000    0.000 figure.py:934(get_facecolor)
#         2    0.000    0.000    0.000    0.000 figure.py:958(set_edgecolor)
#         2    0.000    0.000    0.000    0.000 figure.py:968(set_facecolor)
#        99    0.000    0.000    0.000    0.000 font_manager.py:1043(get_default_size)
#       100    0.001    0.000    0.003    0.000 font_manager.py:1179(findfont)
#       600    0.000    0.000    0.001    0.000 font_manager.py:1233(<genexpr>)
#       100    0.000    0.000    0.000    0.000 font_manager.py:1338(get_font)
#       162    0.001    0.000    0.006    0.000 font_manager.py:620(__init__)
#       440    0.001    0.000    0.002    0.000 font_manager.py:660(__hash__)
#       100    0.000    0.000    0.001    0.000 font_manager.py:670(__eq__)
#       440    0.000    0.000    0.000    0.000 font_manager.py:676(get_family)
#       440    0.000    0.000    0.000    0.000 font_manager.py:688(get_style)
#       440    0.000    0.000    0.000    0.000 font_manager.py:695(get_variant)
#       440    0.000    0.000    0.000    0.000 font_manager.py:701(get_weight)
#       440    0.000    0.000    0.000    0.000 font_manager.py:710(get_stretch)
#       572    0.000    0.000    0.000    0.000 font_manager.py:724(get_size_in_points)
#       440    0.000    0.000    0.000    0.000 font_manager.py:727(get_file)
#       162    0.000    0.000    0.000    0.000 font_manager.py:744(set_family)
#       162    0.000    0.000    0.001    0.000 font_manager.py:757(set_style)
#       162    0.000    0.000    0.000    0.000 font_manager.py:767(set_variant)
#       163    0.001    0.000    0.001    0.000 font_manager.py:776(set_weight)
#       162    0.000    0.000    0.001    0.000 font_manager.py:794(set_stretch)
#       190    0.001    0.000    0.001    0.000 font_manager.py:812(set_size)
#       162    0.000    0.000    0.000    0.000 font_manager.py:837(set_file)
#        38    0.000    0.000    0.001    0.000 font_manager.py:858(copy)
#       324    0.000    0.000    0.000    0.000 font_manager.py:928(_normalize_font_family)
#        28    0.000    0.000    0.000    0.000 fromnumeric.py:1755(_nonzero_dispatcher)
#        28    0.000    0.000    0.000    0.000 fromnumeric.py:1759(nonzero)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:1852(_shape_dispatcher)
# ...
#         8    0.000    0.000    0.000    0.000 transforms.py:2385(transform_path_non_affine)
#   222/168    0.001    0.000    0.005    0.000 transforms.py:2395(get_affine)
#         4    0.000    0.000    0.000    0.000 transforms.py:2415(__init__)
#         4    0.000    0.000    0.000    0.000 transforms.py:2459(get_matrix)
#       231    0.000    0.000    0.002    0.000 transforms.py:2470(composite_transform_factory)
#        39    0.000    0.000    0.000    0.000 transforms.py:2553(__init__)
#   111/110    0.000    0.000    0.000    0.000 transforms.py:2573(get_matrix)
#         2    0.000    0.000    0.000    0.000 transforms.py:2616(__init__)
#        24    0.000    0.000    0.000    0.000 transforms.py:2632(get_matrix)
#       117    0.000    0.000    0.001    0.000 transforms.py:2654(__init__)
#       146    0.000    0.000    0.000    0.000 transforms.py:2668(get_matrix)
#        44    0.000    0.000    0.000    0.000 transforms.py:2694(__init__)
#        44    0.000    0.000    0.001    0.000 transforms.py:2710(_revalidate)
#        44    0.000    0.000    0.001    0.000 transforms.py:2722(get_transformed_points_and_affine)
#        44    0.000    0.000    0.000    0.000 transforms.py:2749(get_affine)
#        14    0.000    0.000    0.000    0.000 transforms.py:276(frozen)
#        45    0.001    0.000    0.001    0.000 transforms.py:2791(nonsingular)
#         8    0.000    0.000    0.001    0.000 transforms.py:280(__array__)
#        88    0.000    0.000    0.000    0.000 transforms.py:2867(_interval_contains_close)
#         8    0.000    0.000    0.000    0.000 transforms.py:287(x0)
#        12    0.000    0.000    0.000    0.000 transforms.py:297(y0)
#         2    0.000    0.000    0.000    0.000 transforms.py:307(x1)
#         6    0.000    0.000    0.000    0.000 transforms.py:337(p1)
#        78    0.000    0.000    0.001    0.000 transforms.py:347(xmin)
#        92    0.000    0.000    0.001    0.000 transforms.py:352(ymin)
#        78    0.000    0.000    0.001    0.000 transforms.py:357(xmax)
#        94    0.000    0.000    0.005    0.000 transforms.py:362(ymax)
#        63    0.000    0.000    0.000    0.000 transforms.py:377(intervalx)
#        89    0.000    0.000    0.000    0.000 transforms.py:386(intervaly)
#         6    0.000    0.000    0.000    0.000 transforms.py:395(width)
#         6    0.000    0.000    0.000    0.000 transforms.py:401(height)
#         4    0.000    0.000    0.000    0.000 transforms.py:407(size)
#     28/27    0.000    0.000    0.001    0.000 transforms.py:413(bounds)
#         3    0.000    0.000    0.000    0.000 transforms.py:419(extents)
#         4    0.000    0.000    0.000    0.000 transforms.py:534(anchored)
#         4    0.000    0.000    0.000    0.000 transforms.py:581(shrunk_to_aspect)
#        90    0.001    0.000    0.002    0.000 transforms.py:671(translated)
#        14    0.000    0.000    0.004    0.000 transforms.py:697(union)
#        14    0.000    0.000    0.001    0.000 transforms.py:702(<listcomp>)
#        14    0.000    0.000    0.001    0.000 transforms.py:703(<listcomp>)
#        14    0.000    0.000    0.001    0.000 transforms.py:704(<listcomp>)
#        14    0.000    0.000    0.001    0.000 transforms.py:705(<listcomp>)
#         2    0.000    0.000    0.001    0.000 transforms.py:708(intersection)
#       254    0.001    0.000    0.003    0.000 transforms.py:726(__init__)
#        35    0.000    0.000    0.001    0.000 transforms.py:762(unit)
#         2    0.000    0.000    0.000    0.000 transforms.py:770(null)
#        37    0.000    0.000    0.001    0.000 transforms.py:778(from_bounds)
#        79    0.000    0.000    0.002    0.000 transforms.py:788(from_extents)
#      1693    0.001    0.000    0.001    0.000 transforms.py:82(__init__)
#         4    0.000    0.000    0.000    0.000 transforms.py:824(update_from_path)
#         4    0.000    0.000    0.000    0.000 transforms.py:860(update_from_data_xy)
#         2    0.000    0.000    0.000    0.000 transforms.py:911(p1)
#         7    0.000    0.000    0.000    0.000 transforms.py:916(intervalx)
#         9    0.000    0.000    0.000    0.000 transforms.py:921(intervaly)
#         6    0.000    0.000    0.000    0.000 transforms.py:938(minposx)
#         8    0.000    0.000    0.000    0.000 transforms.py:942(minposy)
#       569    0.000    0.000    0.000    0.000 transforms.py:946(get_points)
#        10    0.000    0.000    0.001    0.000 transforms.py:964(set)
#        39    0.000    0.000    0.000    0.000 transforms.py:994(__init__)
#        64    0.000    0.000    0.000    0.000 units.py:122(is_numlike)
#     30/16    0.000    0.000    0.001    0.000 units.py:142(get_converter)
#         1    0.000    0.000    0.000    0.000 warnings.py:106(_formatwarnmsg)
#         1    0.000    0.000    0.000    0.000 warnings.py:20(_showwarnmsg_impl)
#         1    0.000    0.000    0.000    0.000 warnings.py:35(_formatwarnmsg_impl)
#         1    0.000    0.000    0.000    0.000 warnings.py:408(__init__)
#         1    0.000    0.000    0.000    0.000 warnings.py:85(_showwarnmsg)
#        12    0.000    0.000    0.000    0.000 weakref.py:44(__new__)
#         2    0.000    0.000    0.000    0.000 weakref.py:51(_cb)
#         1    0.000    0.000    0.000    0.000 weakref.py:73(__eq__)
#         2    0.000    0.000    0.000    0.000 widgets.py:33(__init__)
#       492    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x102a8d6a8}
#       560    0.001    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#        44    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         3    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#         3    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#      4373    0.087    0.000    0.087    0.000 {built-in method builtins.abs}
#       118    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        63    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       205    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#        56    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    3.148    3.148 {built-in method builtins.exec}
#      4970    0.010    0.000    0.010    0.000 {built-in method builtins.getattr}
#      4967    0.003    0.000    0.003    0.000 {built-in method builtins.hasattr}
#   923/582    0.000    0.000    0.002    0.000 {built-in method builtins.hash}
#      1488    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#     10500    0.003    0.000    0.004    0.000 {built-in method builtins.isinstance}
#        65    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       534    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#      2046    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#       285    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#        45    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#      1428    0.001    0.000    0.009    0.000 {built-in method builtins.next}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#      1292    0.000    0.000    0.001    0.000 {built-in method builtins.setattr}
#       366    0.001    0.000    0.001    0.000 {built-in method builtins.sorted}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        76    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#         1    0.002    0.002    0.002    0.002 {built-in method io.open}
#         4    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         8    0.000    0.000    0.000    0.000 {built-in method math.copysign}
#        50    0.000    0.000    0.000    0.000 {built-in method math.cos}
#        48    0.000    0.000    0.000    0.000 {built-in method math.floor}
#        84    0.000    0.000    0.000    0.000 {built-in method math.log10}
#       100    0.000    0.000    0.000    0.000 {built-in method math.radians}
#        50    0.000    0.000    0.000    0.000 {built-in method math.sin}
#         4    0.044    0.011    0.044    0.011 {built-in method matplotlib._image.resample}
#       271    0.001    0.000    0.001    0.000 {built-in method matplotlib._path.affine_transform}
#         8    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.get_path_extents}
#         4    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.update_path_extents}
#         1    0.088    0.088    0.088    0.088 {built-in method matplotlib._png.write_png}
#        31    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#      3562    0.249    0.000    0.249    0.000 {built-in method numpy.array}
# 2445/1970    0.008    0.000    0.046    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        35    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         7    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        58    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        29    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        13    0.006    0.000    0.006    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#      7626    0.002    0.000    0.002    0.000 {function RcParams.__getitem__ at 0x109def378}
#         3    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        16    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#         7    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#        11    0.000    0.000    0.006    0.001 {method 'any' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       924    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.generic' objects}
#       112    0.003    0.000    0.003    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.001    0.001 {method 'clear' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       100    0.000    0.000    0.000    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#        31    0.000    0.000    0.008    0.000 {method 'clip' of 'numpy.ndarray' objects}
#        19    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.generic' objects}
#       589    0.002    0.000    0.002    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       298    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        50    0.002    0.000    0.002    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#         2    0.003    0.002    0.004    0.002 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        44    0.002    0.000    0.002    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        16    0.005    0.000    0.009    0.001 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         2    0.001    0.000    0.001    0.000 {method 'draw_quad_mesh' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        50    0.003    0.000    0.003    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         2    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        22    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       401    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        50    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#       100    0.000    0.000    0.000    0.000 {method 'get_descent' of 'matplotlib.ft2font.FT2Font' objects}
#        50    0.000    0.000    0.000    0.000 {method 'get_width_height' of 'matplotlib.ft2font.FT2Font' objects}
#         4    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.generic' objects}
#       277    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#      6123    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#      1228    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       389    0.001    0.000    0.001    0.000 {method 'match' of 're.Pattern' objects}
#       153    0.000    0.000    0.047    0.000 {method 'max' of 'numpy.ndarray' objects}
#        89    0.000    0.000    0.054    0.001 {method 'min' of 'numpy.ndarray' objects}
#        28    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#       111    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#      6978    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#       185    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1160    0.113    0.000    0.113    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        14    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#       169    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#       291    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#       100    0.001    0.000    0.001    0.000 {method 'round' of 'numpy.generic' objects}
#        64    0.000    0.000    0.000    0.000 {method 'round' of 'numpy.ndarray' objects}
#         8    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#       100    0.013    0.000    0.013    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#        29    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        25    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#      1712    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        28    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         3    0.010    0.003    0.010    0.003 {method 'take' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       786    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#       744    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#     78/72    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.generic' objects}
#   143/139    0.000    0.000    0.002    0.000 {method 'view' of 'numpy.ndarray' objects}
#      4099    1.049    0.000    1.049    0.000 {mkl_fft._pydfti.fft}

# %%
cProfile.run('compute_specg('+str(n_timestamps_given)+')')
# Out:
# /Users/Makbukuska/miniconda3/envs/base2/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys
#          201105 function calls (197352 primitive calls) in 2.063 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        30    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#       201    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(amax)
#       199    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(amin)
#       395    0.000    0.000    0.010    0.000 <__array_function__ internals>:2(any)
#       164    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(around)
#        37    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_1d)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#       102    0.002    0.000    0.005    0.000 <__array_function__ internals>:2(broadcast_arrays)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(can_cast)
#        31    0.000    0.000    0.007    0.000 <__array_function__ internals>:2(clip)
#       115    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(column_stack)
#       162    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(concatenate)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#        12    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(cumsum)
#        35    0.002    0.000    0.002    0.000 <__array_function__ internals>:2(diff)
#       564    0.001    0.000    0.004    0.000 <__array_function__ internals>:2(dot)
#        35    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(hstack)
#        10    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(isclose)
#         4    0.001    0.000    0.028    0.007 <__array_function__ internals>:2(linspace)
#         1    0.000    0.000    0.002    0.002 <__array_function__ internals>:2(meshgrid)
#        17    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(min_scalar_type)
#        66    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(ndim)
#        28    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(nonzero)
#        24    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ptp)
#        14    0.001    0.000    0.002    0.000 <__array_function__ internals>:2(result_type)
#       164    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(round_)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(shape)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(unravel_index)
#        12    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(vstack)
#       128    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         1    0.007    0.007    2.058    2.058 <ipython-input-14-8960d93e9718>:3(compute_specg)
#         1    0.007    0.007    0.458    0.458 <ipython-input-4-60be2dfceb23>:1(my_imshow)
#         1    0.007    0.007    0.035    0.035 <ipython-input-5-615de00c4e98>:1(form_signal)
#      4090    0.273    0.000    0.273    0.000 <ipython-input-8-8a96427a713d>:1(window_function)
#         1    0.280    0.280    0.880    0.880 <ipython-input-8-8a96427a713d>:5(get_specgram)
#         1    0.017    0.017    1.978    1.978 <ipython-input-9-ba3c0e85c62f>:5(plot_specfram)
#         1    0.001    0.001    2.059    2.059 <string>:1(<module>)
#       378    0.000    0.000    0.002    0.000 <string>:1(__new__)
#         4    0.000    0.000    0.000    0.000 __init__.py:1310(debug)
#         1    0.000    0.000    0.000    0.000 __init__.py:1322(get_backend)
#         1    0.000    0.000    0.000    0.000 __init__.py:1342(is_interactive)
#       149    0.000    0.000    0.000    0.000 __init__.py:1373(is_math_text)
#       407    0.000    0.000    0.002    0.000 __init__.py:1382(_to_unmasked_float_array)
#        36    0.002    0.000    0.002    0.000 __init__.py:143(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:1568(isEnabledFor)
#         2    0.000    0.000    0.180    0.090 __init__.py:1598(inner)
#       101    0.000    0.000    0.000    0.000 __init__.py:1616(<lambda>)
#        12    0.000    0.000    0.002    0.000 __init__.py:163(connect)
#        30    0.000    0.000    0.000    0.000 __init__.py:1651(safe_first_element)
#         4    0.000    0.000    0.002    0.000 __init__.py:1667(sanitize_sequence)
#       275    0.004    0.000    0.005    0.000 __init__.py:1673(normalize_kwargs)
#       275    0.000    0.000    0.000    0.000 __init__.py:1760(<listcomp>)
#       275    0.000    0.000    0.000    0.000 __init__.py:1765(<listcomp>)
#         2    0.000    0.000    0.000    0.000 __init__.py:180(_remove_proxy)
#       218    0.000    0.000    0.000    0.000 __init__.py:1906(_str_equal)
#       180    0.000    0.000    0.000    0.000 __init__.py:1916(_str_lower_equal)
#        35    0.000    0.000    0.000    0.000 __init__.py:1947(method)
#      1244    0.004    0.000    0.006    0.000 __init__.py:2012(_setattr_cm)
#       622    0.000    0.000    0.001    0.000 __init__.py:2017(<listcomp>)
#         1    0.001    0.001    0.012    0.012 __init__.py:2030(_warn_external)
#        70    0.000    0.000    0.000    0.000 __init__.py:205(process)
#         2    0.000    0.000    0.000    0.000 __init__.py:2053(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:2065(add)
#         2    0.000    0.000    0.000    0.000 __init__.py:21(get_projection_class)
#      1694    0.001    0.000    0.001    0.000 __init__.py:2151(_check_in_list)
#         6    0.000    0.000    0.000    0.000 __init__.py:232(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:388(to_filehandle)
#         2    0.000    0.000    0.000    0.000 __init__.py:444(open_file_cm)
#         2    0.000    0.000    0.000    0.000 __init__.py:48(get_projection_class)
#        25    0.015    0.001    0.015    0.001 __init__.py:646(__setitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(__init__)
#         7    0.000    0.000    0.000    0.000 __init__.py:690(push)
#         5    0.000    0.000    0.000    0.000 __init__.py:715(clear)
#         3    0.000    0.000    0.000    0.000 __init__.py:720(bubble)
#         5    0.000    0.000    0.000    0.000 __init__.py:76(__init__)
#         4    0.002    0.001    0.137    0.034 __init__.py:794(safe_masked_invalid)
#      7619    0.005    0.000    0.006    0.000 __init__.py:810(__getitem__)
#        10    0.002    0.000    0.002    0.000 __init__.py:85(__hash__)
#         2    0.000    0.000    0.000    0.000 __init__.py:913(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:914(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 __init__.py:916(__contains__)
#        49    0.000    0.000    0.000    0.000 __init__.py:919(clean)
#        49    0.000    0.000    0.000    0.000 __init__.py:922(<listcomp>)
#        45    0.002    0.000    0.002    0.000 __init__.py:968(get_siblings)
#        45    0.000    0.000    0.000    0.000 __init__.py:972(<listcomp>)
#      1491    0.001    0.000    0.010    0.000 _asarray.py:16(asarray)
#       527    0.000    0.000    0.002    0.000 _asarray.py:88(asanyarray)
#         1    0.000    0.000    0.000    0.000 _axes.py:153(set_title)
#         1    0.000    0.000    0.000    0.000 _axes.py:223(set_xlabel)
#         3    0.000    0.000    0.000    0.000 _axes.py:256(set_ylabel)
#         1    0.000    0.000    0.173    0.173 _axes.py:5491(imshow)
#         1    0.000    0.000    0.000    0.000 _axes.py:5689(_pcolorargs)
#         1    0.000    0.000    0.000    0.000 _axes.py:5713(<listcomp>)
#         1    0.000    0.000    0.003    0.003 _axes.py:5992(pcolormesh)
#         3    0.000    0.000    0.000    0.000 _base.py:1133(_set_title_offset_trans)
#         8    0.000    0.000    0.000    0.000 _base.py:1219(get_aspect)
#         2    0.000    0.000    0.000    0.000 _base.py:1222(set_aspect)
#         4    0.002    0.000    0.002    0.001 _base.py:130(__init__)
#         2    0.000    0.000    0.000    0.000 _base.py:1304(set_adjustable)
#         4    0.000    0.000    0.000    0.000 _base.py:1345(get_anchor)
#         2    0.000    0.000    0.000    0.000 _base.py:1358(set_anchor)
#         4    0.000    0.000    0.000    0.000 _base.py:1414(get_data_ratio)
#         4    0.000    0.000    0.000    0.000 _base.py:143(set_prop_cycle)
#         8    0.002    0.000    0.003    0.000 _base.py:1446(apply_aspect)
#         1    0.000    0.000    0.000    0.000 _base.py:1783(_sci)
#         1    0.000    0.000    0.000    0.000 _base.py:1798(_gci)
#         2    0.000    0.000    0.001    0.000 _base.py:1819(add_artist)
#         1    0.000    0.000    0.000    0.000 _base.py:1858(add_collection)
#         1    0.000    0.000    0.000    0.000 _base.py:1878(add_image)
#         3    0.000    0.000    0.000    0.000 _base.py:2061(update_datalim)
#        13    0.000    0.000    0.001    0.000 _base.py:2097(_process_unit_info)
#        26    0.000    0.000    0.001    0.000 _base.py:2100(_process_single_axis)
#         3    0.000    0.000    0.000    0.000 _base.py:2185(use_sticky_edges)
#         3    0.000    0.000    0.002    0.001 _base.py:2388(autoscale_view)
#         2    0.000    0.000    0.000    0.000 _base.py:2415(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _base.py:2416(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _base.py:2417(<listcomp>)
#         6    0.000    0.000    0.002    0.000 _base.py:2425(handle_single_axis)
#         2    0.000    0.000    0.000    0.000 _base.py:2432(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _base.py:2434(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _base.py:2453(<listcomp>)
#        12    0.000    0.000    0.000    0.000 _base.py:2500(_get_axis_list)
#         4    0.000    0.000    0.011    0.003 _base.py:2503(_update_title_position)
#         4    0.000    0.000    0.522    0.130 _base.py:2573(draw)
#         2    0.000    0.000    0.000    0.000 _base.py:2619(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _base.py:2683(set_frame_on)
#         2    0.000    0.000    0.000    0.000 _base.py:2708(set_axisbelow)
#         6    0.000    0.000    0.040    0.007 _base.py:2744(grid)
#         5    0.000    0.000    0.004    0.001 _base.py:2918(tick_params)
#         2    0.000    0.000    0.000    0.000 _base.py:3027(set_axis_on)
#         1    0.000    0.000    0.000    0.000 _base.py:3050(xaxis_inverted)
#         5    0.000    0.000    0.000    0.000 _base.py:3064(get_xbound)
#         1    0.000    0.000    0.000    0.000 _base.py:3080(set_xbound)
#        10    0.000    0.000    0.000    0.000 _base.py:3120(get_xlim)
#        24    0.000    0.000    0.001    0.000 _base.py:3143(_validate_converted_limits)
#         5    0.000    0.000    0.003    0.001 _base.py:3161(set_xlim)
#        15    0.000    0.000    0.000    0.000 _base.py:3288(get_xscale)
#         1    0.000    0.000    0.001    0.001 _base.py:3298(set_xscale)
#         1    0.001    0.001    0.005    0.005 _base.py:3332(get_xticks)
#         1    0.000    0.000    0.015    0.015 _base.py:3377(get_xticklabels)
#         1    0.000    0.000    0.000    0.000 _base.py:3449(yaxis_inverted)
#         5    0.000    0.000    0.000    0.000 _base.py:3463(get_ybound)
#         1    0.000    0.000    0.000    0.000 _base.py:3479(set_ybound)
#        12    0.000    0.000    0.000    0.000 _base.py:3519(get_ylim)
#         7    0.000    0.000    0.001    0.000 _base.py:3542(set_ylim)
#        17    0.000    0.000    0.000    0.000 _base.py:3670(get_yscale)
#         1    0.000    0.000    0.001    0.001 _base.py:3680(set_yscale)
#         1    0.000    0.000    0.003    0.003 _base.py:3713(get_yticks)
#         1    0.000    0.000    0.009    0.009 _base.py:3757(get_yticklabels)
#         3    0.000    0.000    0.000    0.000 _base.py:3915(set_navigate)
#         2    0.000    0.000    0.000    0.000 _base.py:3931(set_navigate_mode)
#         2    0.003    0.001    0.115    0.058 _base.py:421(__init__)
#        10    0.000    0.000    0.000    0.000 _base.py:4248(get_children)
#         1    0.000    0.000    0.000    0.000 _base.py:4477(get_shared_x_axes)
#         1    0.000    0.000    0.000    0.000 _base.py:4481(get_shared_y_axes)
#        12    0.000    0.000    0.000    0.000 _base.py:576(get_window_extent)
#         2    0.002    0.001    0.030    0.015 _base.py:594(_init_axis)
#         2    0.000    0.000    0.004    0.002 _base.py:604(set_figure)
#         2    0.000    0.000    0.002    0.001 _base.py:624(_set_lim_and_transforms)
#   211/115    0.000    0.000    0.001    0.000 _base.py:660(get_xaxis_transform)
#        23    0.002    0.000    0.003    0.000 _base.py:684(get_xaxis_text1_transform)
#        23    0.000    0.000    0.001    0.000 _base.py:710(get_xaxis_text2_transform)
#   310/170    0.000    0.000    0.001    0.000 _base.py:736(get_yaxis_transform)
#        34    0.002    0.000    0.003    0.000 _base.py:760(get_yaxis_text1_transform)
#        34    0.000    0.000    0.001    0.000 _base.py:786(get_yaxis_text2_transform)
#         6    0.000    0.000    0.002    0.000 _base.py:812(_update_transScale)
#         8    0.000    0.000    0.000    0.000 _base.py:822(get_position)
#         9    0.000    0.000    0.001    0.000 _base.py:871(_set_position)
#         2    0.000    0.000    0.000    0.000 _base.py:898(set_axes_locator)
#         8    0.000    0.000    0.000    0.000 _base.py:909(get_axes_locator)
#        10    0.000    0.000    0.000    0.000 _base.py:915(_set_artist_props)
#         2    0.000    0.000    0.002    0.001 _base.py:925(_gen_axes_patch)
#         2    0.000    0.000    0.008    0.004 _base.py:942(_gen_axes_spines)
#        10    0.000    0.000    0.008    0.001 _base.py:957(<genexpr>)
#         2    0.001    0.000    0.064    0.032 _base.py:960(cla)
#      4091    0.008    0.000    0.010    0.000 _float_utils.py:55(__downcast_float128_array)
#         3    0.000    0.000    0.000    0.000 _internal.py:908(__init__)
#         1    0.001    0.001    0.001    0.001 _layoutbox.py:655(nonetree)
#        24    0.000    0.000    0.000    0.000 _methods.py:228(_ptp)
#       153    0.000    0.000    0.031    0.000 _methods.py:28(_amax)
#        89    0.002    0.000    0.032    0.000 _methods.py:32(_amin)
#        28    0.000    0.000    0.000    0.000 _methods.py:36(_sum)
#        15    0.000    0.000    0.002    0.000 _methods.py:44(_any)
#        23    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#        62    0.000    0.000    0.001    0.000 _methods.py:63(_clip_dep_is_scalar_nan)
#        62    0.000    0.000    0.000    0.000 _methods.py:73(_clip_dep_is_byte_swapped)
#        31    0.006    0.000    0.006    0.000 _methods.py:78(_clip_dep_invoke_with_casting)
#        31    0.000    0.000    0.007    0.000 _methods.py:97(_clip)
#      4091    0.002    0.000    0.002    0.000 _numpy_fft.py:67(_unitary)
#      4091    0.011    0.000    0.284    0.000 _numpy_fft.py:74(fft)
#        14    0.000    0.000    0.000    0.000 _pylab_helpers.py:100(get_active)
#         1    0.002    0.002    0.002    0.002 _pylab_helpers.py:110(set_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:116(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:30(get_fig_manager)
#         5    0.000    0.000    0.000    0.000 _subplots.py:110(get_subplotspec)
#         1    0.000    0.000    0.000    0.000 _subplots.py:114(set_subplotspec)
#         3    0.000    0.000    0.014    0.005 _subplots.py:122(update_params)
#         2    0.002    0.001    0.134    0.067 _subplots.py:18(__init__)
#        29    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#        29    0.000    0.000    0.000    0.000 _ufunc_config.py:39(seterr)
#        13    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#        13    0.000    0.000    0.000    0.000 _ufunc_config.py:441(__enter__)
#        13    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#       560    0.000    0.000    0.003    0.000 abc.py:137(__instancecheck__)
#        44    0.000    0.000    0.000    0.000 abc.py:141(__subclasscheck__)
#         4    0.000    0.000    0.000    0.000 artist.py:1001(get_zorder)
#       129    0.000    0.000    0.000    0.000 artist.py:1005(set_zorder)
#       364    0.000    0.000    0.000    0.000 artist.py:1020(sticky_edges)
#        85    0.000    0.000    0.001    0.000 artist.py:1043(update_from)
#       275    0.004    0.000    0.013    0.000 artist.py:1064(set)
#         8    0.000    0.000    0.000    0.000 artist.py:1070(<lambda>)
#        10    0.000    0.000    0.000    0.000 artist.py:1171(mouseover)
#         2    0.000    0.000    0.000    0.000 artist.py:163(have_units)
#       461    0.000    0.000    0.001    0.000 artist.py:170(convert_xunits)
#       469    0.000    0.000    0.001    0.000 artist.py:182(convert_yunits)
#      3508    0.001    0.000    0.001    0.000 artist.py:194(axes)
#       461    0.000    0.000    0.000    0.000 artist.py:199(axes)
# 8153/6839    0.007    0.000    0.009    0.000 artist.py:219(stale)
#     334/2    0.003    0.000    0.528    0.264 artist.py:30(draw_wrapper)
#      1631    0.001    0.000    0.001    0.000 artist.py:338(pchanged)
#        10    0.000    0.000    0.000    0.000 artist.py:352(is_transform_set)
#       325    0.000    0.000    0.001    0.000 artist.py:360(set_transform)
#       256    0.000    0.000    0.000    0.000 artist.py:373(get_transform)
#       813    0.001    0.000    0.003    0.000 artist.py:49(_stale_axes_callback)
#         2    0.000    0.000    0.000    0.000 artist.py:541(get_url)
#         1    0.000    0.000    0.000    0.000 artist.py:545(set_url)
#       114    0.000    0.000    0.000    0.000 artist.py:555(get_gid)
#        16    0.000    0.000    0.000    0.000 artist.py:569(get_snap)
#        60    0.000    0.000    0.000    0.000 artist.py:608(get_sketch_params)
#       110    0.000    0.000    0.000    0.000 artist.py:666(get_path_effects)
#         5    0.000    0.000    0.000    0.000 artist.py:669(get_figure)
#       377    0.001    0.000    0.001    0.000 artist.py:673(set_figure)
#        10    0.000    0.000    0.000    0.000 artist.py:697(set_clip_box)
#        33    0.000    0.000    0.009    0.000 artist.py:709(set_clip_path)
#       378    0.013    0.000    0.017    0.000 artist.py:74(__init__)
#        55    0.000    0.000    0.000    0.000 artist.py:763(get_alpha)
#       734    0.000    0.000    0.000    0.000 artist.py:770(get_visible)
#      8175    0.001    0.000    0.001    0.000 artist.py:774(get_animated)
#         2    0.000    0.000    0.000    0.000 artist.py:797(get_clip_path)
#       114    0.000    0.000    0.000    0.000 artist.py:828(_set_gc_clip)
#       668    0.000    0.000    0.000    0.000 artist.py:838(get_rasterized)
#         1    0.000    0.000    0.000    0.000 artist.py:842(set_rasterized)
#       668    0.000    0.000    0.000    0.000 artist.py:858(get_agg_filter)
#        59    0.000    0.000    0.000    0.000 artist.py:893(set_alpha)
#       407    0.000    0.000    0.001    0.000 artist.py:905(set_visible)
#       603    0.003    0.000    0.018    0.000 artist.py:942(update)
#       205    0.001    0.000    0.001    0.000 artist.py:946(_update_property)
#       603    0.002    0.000    0.003    0.000 artist.py:974(<listcomp>)
#         2    0.000    0.000    0.000    0.000 artist.py:981(get_label)
#         4    0.000    0.000    0.000    0.000 artist.py:985(set_label)
#         8    0.000    0.000    0.000    0.000 axis.py:1026(_set_artist_props)
#        16    0.001    0.000    0.047    0.003 axis.py:1074(_update_ticks)
#        16    0.000    0.000    0.030    0.002 axis.py:1147(_get_tick_bboxes)
#        16    0.000    0.000    0.019    0.001 axis.py:1149(<listcomp>)
#        16    0.000    0.000    0.011    0.001 axis.py:1151(<listcomp>)
#         8    0.000    0.000    0.121    0.015 axis.py:1195(draw)
#         2    0.000    0.000    0.023    0.012 axis.py:1250(get_majorticklabels)
#         2    0.000    0.000    0.000    0.000 axis.py:1253(<listcomp>)
#         2    0.000    0.000    0.000    0.000 axis.py:1254(<listcomp>)
#         2    0.000    0.000    0.023    0.012 axis.py:1264(get_ticklabels)
#        20    0.000    0.000    0.027    0.001 axis.py:1322(get_majorticklocs)
#        16    0.000    0.000    0.015    0.001 axis.py:1326(get_minorticklocs)
#        16    0.000    0.000    0.000    0.000 axis.py:1340(<listcomp>)
#         2    0.000    0.000    0.007    0.003 axis.py:1344(get_ticklocs)
#        17    0.000    0.000    0.006    0.000 axis.py:1374(_copy_tick_props)
#        14    0.000    0.000    0.000    0.000 axis.py:1388(get_major_locator)
#        19    0.000    0.000    0.029    0.002 axis.py:1404(get_major_ticks)
#        17    0.000    0.000    0.000    0.000 axis.py:1418(get_minor_ticks)
#        12    0.000    0.000    0.040    0.003 axis.py:1432(grid)
#        12    0.000    0.000    0.000    0.000 axis.py:1462(<dictcomp>)
#        14    0.000    0.000    0.001    0.000 axis.py:1480(update_units)
#        24    0.000    0.000    0.000    0.000 axis.py:1502(_update_axisinfo)
#        18    0.000    0.000    0.000    0.000 axis.py:1536(have_units)
#        64    0.000    0.000    0.001    0.000 axis.py:1539(convert_units)
#        57    0.000    0.000    0.000    0.000 axis.py:154(<dictcomp>)
#        24    0.000    0.000    0.000    0.000 axis.py:1556(set_units)
#         4    0.000    0.000    0.000    0.000 axis.py:1582(set_label_text)
#        35    0.000    0.000    0.000    0.000 axis.py:1603(set_major_formatter)
#        34    0.000    0.000    0.000    0.000 axis.py:1619(set_minor_formatter)
#        36    0.000    0.000    0.000    0.000 axis.py:1635(set_major_locator)
#        35    0.000    0.000    0.000    0.000 axis.py:1653(set_minor_locator)
#         2    0.000    0.000    0.000    0.000 axis.py:1741(set_ticks)
#        12    0.000    0.000    0.000    0.000 axis.py:1818(_get_ticks_position)
#        36    0.000    0.000    0.000    0.000 axis.py:1834(<genexpr>)
#        12    0.000    0.000    0.000    0.000 axis.py:1855(get_label_position)
#       110    0.000    0.000    0.001    0.000 axis.py:1881(getter)
#        23    0.000    0.000    0.043    0.002 axis.py:1928(_get_tick)
#         2    0.002    0.001    0.007    0.003 axis.py:1935(_get_label)
#         2    0.000    0.000    0.002    0.001 axis.py:1953(_get_offset_text)
#        57    0.000    0.000    0.000    0.000 axis.py:198(_set_labelrotation)
#         4    0.000    0.000    0.008    0.002 axis.py:1985(_get_tick_boxes_siblings)
#         4    0.000    0.000    0.010    0.003 axis.py:2004(_update_label_position)
#         4    0.000    0.000    0.001    0.000 axis.py:2047(_update_offset_text_position)
#        12    0.000    0.000    0.000    0.000 axis.py:2140(get_ticks_position)
#         5    0.000    0.000    0.000    0.000 axis.py:2153(get_minpos)
#        57    0.000    0.000    0.000    0.000 axis.py:216(get_tick_padding)
#        10    0.000    0.000    0.013    0.001 axis.py:2179(get_tick_space)
#        34    0.000    0.000    0.045    0.001 axis.py:2217(_get_tick)
#         2    0.000    0.000    0.002    0.001 axis.py:2224(_get_label)
#         2    0.000    0.000    0.002    0.001 axis.py:2244(_get_offset_text)
#         1    0.000    0.000    0.000    0.000 axis.py:2260(set_label_position)
#         4    0.000    0.000    0.016    0.004 axis.py:2279(_get_tick_boxes_siblings)
#         4    0.000    0.000    0.018    0.004 axis.py:2298(_update_label_position)
#        12    0.000    0.000    0.007    0.001 axis.py:230(set_clip_path)
#         4    0.000    0.000    0.000    0.000 axis.py:2340(_update_offset_text_position)
#         1    0.000    0.000    0.000    0.000 axis.py:2351(set_offset_position)
#         1    0.000    0.000    0.001    0.001 axis.py:2387(set_ticks_position)
#         7    0.000    0.000    0.000    0.000 axis.py:2460(get_minpos)
#        18    0.000    0.000    0.020    0.001 axis.py:2486(get_tick_space)
#        88    0.000    0.000    0.000    0.000 axis.py:285(get_loc)
#        44    0.000    0.000    0.031    0.001 axis.py:289(draw)
#        88    0.000    0.000    0.000    0.000 axis.py:301(set_label1)
#        88    0.000    0.000    0.000    0.000 axis.py:314(set_label2)
#       285    0.000    0.000    0.001    0.000 axis.py:325(_set_artist_props)
#        55    0.002    0.000    0.016    0.000 axis.py:332(_apply_params)
#       275    0.000    0.000    0.000    0.000 axis.py:340(<genexpr>)
#        55    0.000    0.000    0.000    0.000 axis.py:359(<dictcomp>)
#        55    0.000    0.000    0.000    0.000 axis.py:370(<dictcomp>)
#        55    0.000    0.000    0.000    0.000 axis.py:381(<dictcomp>)
#        23    0.000    0.000    0.003    0.000 axis.py:405(_get_text1_transform)
#        23    0.000    0.000    0.001    0.000 axis.py:408(_get_text2_transform)
#        23    0.000    0.000    0.000    0.000 axis.py:411(apply_tickdir)
#        23    0.000    0.000    0.007    0.000 axis.py:425(_get_text1)
#        23    0.000    0.000    0.009    0.000 axis.py:442(_get_text2)
#        23    0.000    0.000    0.007    0.000 axis.py:458(_get_tick1line)
#        23    0.000    0.000    0.006    0.000 axis.py:469(_get_tick2line)
#        23    0.000    0.000    0.011    0.000 axis.py:484(_get_gridline)
#        59    0.000    0.000    0.001    0.000 axis.py:500(update_position)
#        34    0.000    0.000    0.003    0.000 axis.py:522(_get_text1_transform)
#        34    0.000    0.000    0.001    0.000 axis.py:525(_get_text2_transform)
#        34    0.000    0.000    0.000    0.000 axis.py:528(apply_tickdir)
#        34    0.000    0.000    0.006    0.000 axis.py:543(_get_text1)
#        34    0.000    0.000    0.006    0.000 axis.py:558(_get_text2)
#        57    0.002    0.000    0.087    0.002 axis.py:56(__init__)
#        34    0.000    0.000    0.010    0.000 axis.py:573(_get_tick1line)
#        34    0.000    0.000    0.008    0.000 axis.py:588(_get_tick2line)
#        34    0.000    0.000    0.010    0.000 axis.py:602(_get_gridline)
#        86    0.000    0.000    0.001    0.000 axis.py:617(update_position)
#      12/8    0.000    0.000    0.036    0.004 axis.py:658(__get__)
#         4    0.000    0.000    0.025    0.006 axis.py:715(__init__)
#        16    0.000    0.000    0.000    0.000 axis.py:759(get_remove_overlapping_locs)
#       118    0.000    0.000    0.000    0.000 axis.py:792(get_transform)
#        32    0.000    0.000    0.000    0.000 axis.py:795(get_scale)
#        34    0.000    0.000    0.016    0.000 axis.py:798(_set_scale)
#        12    0.000    0.000    0.000    0.000 axis.py:807(limit_range_for_scale)
#        24    0.000    0.000    0.015    0.001 axis.py:819(cla)
#        32    0.000    0.000    0.000    0.000 axis.py:842(reset_ticks)
#        23    0.000    0.000    0.044    0.002 axis.py:862(set_tick_params)
#        23    0.000    0.000    0.000    0.000 axis.py:900(_translate_tick_kw)
#         4    0.000    0.000    0.016    0.004 axis.py:945(set_clip_path)
#         2    0.000    0.000    0.000    0.000 axis.py:988(get_inverted)
#         1    0.002    0.002    0.002    0.002 backend_agg.py:102(_update_methods)
#        16    0.000    0.000    0.005    0.000 backend_agg.py:119(draw_path)
#        50    0.001    0.000    0.014    0.000 backend_agg.py:164(draw_text)
#        50    0.000    0.000    0.009    0.000 backend_agg.py:193(get_text_width_height_descent)
#        50    0.000    0.000    0.000    0.000 backend_agg.py:237(get_canvas_width_height)
#       100    0.000    0.000    0.004    0.000 backend_agg.py:241(_get_agg_font)
#        88    0.000    0.000    0.000    0.000 backend_agg.py:254(points_to_pixels)
#         1    0.000    0.000    0.001    0.001 backend_agg.py:267(clear)
#         6    0.000    0.000    0.000    0.000 backend_agg.py:270(option_image_nocomposite)
#         2    0.000    0.000    0.534    0.267 backend_agg.py:382(draw)
#         3    0.000    0.000    0.006    0.002 backend_agg.py:393(get_renderer)
#         1    0.002    0.002    0.366    0.366 backend_agg.py:450(print_png)
#       100    0.000    0.000    0.000    0.000 backend_agg.py:49(get_hinting_flag)
#         1    0.003    0.003    0.005    0.005 backend_agg.py:80(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1225(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1254(__init__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:150(__init__)
#       170    0.000    0.000    0.000    0.000 backend_bases.py:154(open_group)
#         2    0.004    0.002    0.006    0.003 backend_bases.py:1581(__init__)
#       170    0.000    0.000    0.000    0.000 backend_bases.py:161(close_group)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1633(_idle_draw_cntx)
#         4    0.000    0.000    0.000    0.000 backend_bases.py:1639(is_saving)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1656(draw_event)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1889(draw)
#         1    0.000    0.000    0.256    0.256 backend_bases.py:1892(draw_idle)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1939(_get_output_canvas)
#         1    0.000    0.000    0.367    0.367 backend_bases.py:1958(print_figure)
#         7    0.001    0.000    0.003    0.000 backend_bases.py:2141(mpl_connect)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2482(__init__)
#         3    0.000    0.000    0.000    0.000 backend_bases.py:2500(notify_axes_change)
#         1    0.005    0.005    0.048    0.048 backend_bases.py:3244(new_figure_manager)
#         1    0.000    0.000    0.003    0.003 backend_bases.py:3254(new_figure_manager_given_figure)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3262(draw_if_interactive)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:451(get_image_magnification)
#        50    0.000    0.000    0.000    0.000 backend_bases.py:635(flipy)
#       114    0.000    0.000    0.004    0.000 backend_bases.py:654(new_gc)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:683(start_rasterizing)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:690(stop_rasterizing)
#       114    0.001    0.000    0.003    0.000 backend_bases.py:718(__init__)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:759(restore)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:788(get_clip_path)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:798(get_dashes)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:840(get_snap)
#        68    0.000    0.000    0.000    0.000 backend_bases.py:851(set_alpha)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:868(set_antialiased)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:873(set_capstyle)
#         6    0.000    0.000    0.000    0.000 backend_bases.py:880(set_clip_rectangle)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:886(set_clip_path)
#        16    0.000    0.000    0.000    0.000 backend_bases.py:897(set_dashes)
#       178    0.000    0.000    0.000    0.000 backend_bases.py:918(set_foreground)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:938(set_joinstyle)
#        62    0.000    0.000    0.000    0.000 backend_bases.py:945(set_linewidth)
#        68    0.000    0.000    0.000    0.000 backend_bases.py:949(set_url)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:953(set_gid)
#        60    0.000    0.000    0.000    0.000 backend_bases.py:957(set_snap)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:972(get_hatch)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:976(get_hatch_path)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:983(get_hatch_color)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:991(get_hatch_linewidth)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:995(get_sketch_params)
#         5    0.004    0.001    0.004    0.001 cm.py:155(get_cmap)
#         2    0.000    0.000    0.004    0.002 cm.py:193(__init__)
#         3    0.001    0.000    0.033    0.011 cm.py:223(to_rgba)
#         1    0.000    0.000    0.000    0.000 cm.py:293(set_array)
#         3    0.000    0.000    0.000    0.000 cm.py:303(get_array)
#         1    0.000    0.000    0.000    0.000 cm.py:315(set_clim)
#         1    0.000    0.000    0.000    0.000 cm.py:345(set_cmap)
#         1    0.000    0.000    0.000    0.000 cm.py:357(set_norm)
#         3    0.000    0.000    0.022    0.007 cm.py:386(autoscale_None)
#         2    0.000    0.000    0.000    0.000 cm.py:403(check_update)
#         6    0.000    0.000    0.000    0.000 cm.py:413(changed)
#         2    0.000    0.000    0.000    0.000 collections.py:174(get_offset_transform)
#         1    0.000    0.000    0.001    0.001 collections.py:1910(__init__)
#         2    0.000    0.000    0.001    0.001 collections.py:2002(draw)
#         1    0.000    0.000    0.000    0.000 collections.py:335(set_pickradius)
#         1    0.000    0.000    0.000    0.000 collections.py:378(set_urls)
#         1    0.000    0.000    0.000    0.000 collections.py:390(set_hatch)
#         1    0.000    0.000    0.000    0.000 collections.py:455(set_offset_position)
#         1    0.000    0.000    0.000    0.000 collections.py:483(set_linewidth)
#         1    0.000    0.000    0.000    0.000 collections.py:505(set_linestyle)
#         2    0.000    0.000    0.000    0.000 collections.py:584(_bcast_lwls)
#         2    0.000    0.000    0.000    0.000 collections.py:617(<listcomp>)
#         1    0.000    0.000    0.000    0.000 collections.py:622(set_antialiased)
#         2    0.000    0.000    0.000    0.000 collections.py:651(_set_facecolor)
#         1    0.000    0.000    0.000    0.000 collections.py:664(set_facecolor)
#         2    0.000    0.000    0.000    0.000 collections.py:680(get_facecolor)
#         2    0.000    0.000    0.000    0.000 collections.py:683(get_edgecolor)
#         2    0.000    0.000    0.000    0.000 collections.py:689(_set_edgecolor)
#         1    0.000    0.000    0.000    0.000 collections.py:717(set_edgecolor)
#         1    0.000    0.000    0.000    0.000 collections.py:730(set_alpha)
#         2    0.000    0.000    0.000    0.000 collections.py:748(get_linewidth)
#         2    0.000    0.000    0.001    0.000 collections.py:754(update_scalarmappable)
#         1    0.000    0.000    0.000    0.000 collections.py:90(__init__)
#         2    0.000    0.000    0.000    0.000 colorbar.py:1006(_uniform_y)
#         1    0.000    0.000    0.003    0.003 colorbar.py:1070(_mesh)
#         1    0.000    0.000    0.019    0.019 colorbar.py:1155(__init__)
#         1    0.001    0.001    0.030    0.030 colorbar.py:1471(make_axes_gridspec)
#         1    0.001    0.001    0.020    0.020 colorbar.py:1626(colorbar_factory)
#         1    0.000    0.000    0.000    0.000 colorbar.py:228(__init__)
#         8    0.000    0.000    0.010    0.001 colorbar.py:240(tick_values)
#         1    0.002    0.002    0.018    0.018 colorbar.py:398(__init__)
#         2    0.000    0.000    0.000    0.000 colorbar.py:462(_extend_lower)
#         2    0.000    0.000    0.000    0.000 colorbar.py:466(_extend_upper)
#         1    0.000    0.000    0.000    0.000 colorbar.py:470(_patch_ax)
#         1    0.000    0.000    0.014    0.014 colorbar.py:476(draw_all)
#         1    0.000    0.000    0.001    0.001 colorbar.py:497(config_axis)
#         1    0.000    0.000    0.000    0.000 colorbar.py:511(_get_ticker_locator_formatter)
#         3    0.000    0.000    0.000    0.000 colorbar.py:563(_use_auto_colorbar_locator)
#         1    0.000    0.000    0.002    0.002 colorbar.py:573(_reset_locator_formatter_scale)
#         1    0.000    0.000    0.000    0.000 colorbar.py:593(update_ticks)
#         1    0.000    0.000    0.003    0.003 colorbar.py:695(_config_axes)
#         2    0.000    0.000    0.000    0.000 colorbar.py:729(_set_label)
#         1    0.000    0.000    0.000    0.000 colorbar.py:736(set_label)
#         1    0.000    0.000    0.000    0.000 colorbar.py:742(_outline)
#         1    0.000    0.000    0.003    0.003 colorbar.py:767(_add_solids)
#       2/1    0.000    0.000    0.004    0.004 colorbar.py:863(_process_values)
#         1    0.000    0.000    0.000    0.000 colorbar.py:948(_find_range)
#         1    0.000    0.000    0.000    0.000 colorbar.py:957(_central_N)
#         5    0.000    0.000    0.000    0.000 colors.py:1005(scaled)
#         4    0.000    0.000    0.000    0.000 colors.py:105(_sanitize_extrema)
#       388    0.000    0.000    0.003    0.000 colors.py:115(_is_nth_color)
#       388    0.004    0.000    0.013    0.000 colors.py:149(to_rgba)
#         4    0.000    0.000    0.000    0.000 colors.py:254(to_rgba_array)
#         3    0.007    0.002    0.032    0.011 colors.py:480(__call__)
#         2    0.000    0.000    0.000    0.000 colors.py:891(__init__)
#        17    0.000    0.000    0.007    0.000 colors.py:913(process_value)
#         3    0.003    0.001    0.008    0.003 colors.py:944(__call__)
#         4    0.000    0.000    0.005    0.001 colors.py:979(inverse)
#         8    0.002    0.000    0.022    0.003 colors.py:997(autoscale_None)
#       690    0.001    0.000    0.008    0.000 contextlib.py:107(__enter__)
#       690    0.001    0.000    0.003    0.000 contextlib.py:116(__exit__)
#       690    0.001    0.000    0.006    0.000 contextlib.py:237(helper)
#       690    0.005    0.000    0.005    0.000 contextlib.py:81(__init__)
#         3    0.000    0.000    0.000    0.000 copy.py:268(_reconstruct)
#         3    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         3    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
#         3    0.000    0.000    0.000    0.000 core.py:1005(__call__)
#        40    0.000    0.000    0.000    0.000 core.py:1278(_replace_dtype_fields_recursive)
#        40    0.000    0.000    0.000    0.000 core.py:1310(_replace_dtype_fields)
#        40    0.000    0.000    0.000    0.000 core.py:1324(make_mask_descr)
#       130    0.000    0.000    0.000    0.000 core.py:1357(getmask)
#         6    0.000    0.000    0.000    0.000 core.py:1419(getmaskarray)
#         7    0.000    0.000    0.002    0.000 core.py:1540(_shrink_mask)
#         3    0.001    0.000    0.001    0.000 core.py:1550(make_mask)
#         6    0.000    0.000    0.000    0.000 core.py:1639(make_mask_none)
#         3    0.000    0.000    0.001    0.000 core.py:1689(mask_or)
#         6    0.000    0.000    0.000    0.000 core.py:1813(_check_mask_axis)
#         8    0.000    0.000    0.000    0.000 core.py:210(_recursive_fill_value)
#         8    0.000    0.000    0.000    0.000 core.py:225(_get_dtype_of)
#         4    0.047    0.012    0.047    0.012 core.py:2331(masked_invalid)
#         2    0.000    0.000    0.000    0.000 core.py:235(default_fill_value)
#         6    0.000    0.000    0.000    0.000 core.py:2578(wrapped_method)
#        31    0.002    0.000    0.011    0.000 core.py:2773(__new__)
#         2    0.000    0.000    0.000    0.000 core.py:280(_scalar_fill_value)
#         6    0.000    0.000    0.000    0.000 core.py:290(_extremum_fill_value)
#        94    0.001    0.000    0.001    0.000 core.py:2903(_update_from)
#         6    0.000    0.000    0.000    0.000 core.py:292(_scalar_fill_value)
#        75    0.001    0.000    0.002    0.000 core.py:2929(__array_finalize__)
#         3    0.000    0.000    0.002    0.001 core.py:3022(__array_wrap__)
#         3    0.000    0.000    0.000    0.000 core.py:3040(<listcomp>)
#         3    0.000    0.000    0.000    0.000 core.py:305(minimum_fill_value)
#         5    0.000    0.000    0.000    0.000 core.py:3078(view)
#        30    0.000    0.000    0.000    0.000 core.py:3161(__getitem__)
#        16    0.000    0.000    0.000    0.000 core.py:3178(_scalar_heuristic)
#       176    0.000    0.000    0.000    0.000 core.py:3347(dtype)
#        44    0.000    0.000    0.000    0.000 core.py:3363(shape)
#         2    0.000    0.000    0.000    0.000 core.py:3367(shape)
#         8    0.000    0.000    0.000    0.000 core.py:3446(mask)
#         4    0.001    0.000    0.003    0.001 core.py:3541(shrink_mask)
#         3    0.000    0.000    0.000    0.000 core.py:356(maximum_fill_value)
#        79    0.000    0.000    0.000    0.000 core.py:3577(_get_data)
#         2    0.000    0.000    0.000    0.000 core.py:3607(fill_value)
#         9    0.000    0.000    0.000    0.000 core.py:3663(filled)
#         3    0.000    0.000    0.000    0.000 core.py:3960(_delegate_binop)
#         3    0.000    0.000    0.000    0.000 core.py:4098(__mul__)
#         2    0.000    0.000    0.000    0.000 core.py:439(_check_fill_value)
#         1    0.000    0.000    0.000    0.000 core.py:4483(ravel)
#         4    0.000    0.000    0.000    0.000 core.py:4537(reshape)
#         3    0.000    0.000    0.031    0.010 core.py:5604(min)
#         3    0.000    0.000    0.030    0.010 core.py:5734(max)
#         4    0.000    0.000    0.000    0.000 core.py:5879(<lambda>)
#        21    0.000    0.000    0.000    0.000 core.py:593(filled)
#         3    0.000    0.000    0.000    0.000 core.py:639(get_masked_subclass)
#        23    0.000    0.000    0.011    0.000 core.py:6415(array)
#         2    0.000    0.000    0.000    0.000 core.py:6432(is_masked)
#         3    0.000    0.000    0.000    0.000 core.py:653(<listcomp>)
#        27    0.000    0.000    0.000    0.000 core.py:666(getdata)
#         6    0.000    0.000    0.000    0.000 core.py:7778(asarray)
#         2    0.000    0.000    0.000    0.000 core.py:778(is_string_or_list_of_strings)
#         4    0.000    0.000    0.000    0.000 core.py:781(<genexpr>)
#        26    0.000    0.000    0.000    0.000 cycler.py:138(keys)
#        26    0.000    0.000    0.000    0.000 cycler.py:225(__iter__)
#       242    0.000    0.000    0.000    0.000 cycler.py:227(<genexpr>)
#        22    0.005    0.000    0.005    0.000 cycler.py:349(by_key)
#        44    0.000    0.000    0.000    0.000 cycler.py:371(<genexpr>)
#         1    0.000    0.000    0.000    0.000 decorators.py:41(wrapper)
#       2/1    0.002    0.001    0.176    0.176 deprecation.py:358(wrapper)
#         3    0.000    0.000    0.000    0.000 figure.py:100(_entry_from_axes)
#         3    0.000    0.000    0.000    0.000 figure.py:101(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 figure.py:1072(_make_key)
#         2    0.000    0.000    0.000    0.000 figure.py:1075(fixitems)
#         3    0.000    0.000    0.000    0.000 figure.py:108(bubble)
#         2    0.000    0.000    0.000    0.000 figure.py:1091(fixlist)
#         2    0.002    0.001    0.002    0.001 figure.py:1102(_process_projection_requirements)
#         2    0.000    0.000    0.000    0.000 figure.py:115(add)
#         2    0.002    0.001    0.138    0.069 figure.py:1261(add_subplot)
#         2    0.000    0.000    0.000    0.000 figure.py:1418(_add_axes_internal)
#        20    0.000    0.000    0.000    0.000 figure.py:145(current_key_axes)
#         7    0.000    0.000    0.000    0.000 figure.py:157(__call__)
#         2    0.000    0.000    0.000    0.000 figure.py:160(__contains__)
#         1    0.002    0.002    0.002    0.002 figure.py:1624(clf)
#         2    0.000    0.000    0.528    0.264 figure.py:1661(draw)
#         6    0.000    0.000    0.000    0.000 figure.py:1675(<genexpr>)
#         4    0.000    0.000    0.000    0.000 figure.py:1676(<lambda>)
#         4    0.000    0.000    0.000    0.000 figure.py:168(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:1882(_set_artist_props)
#        12    0.000    0.000    0.110    0.009 figure.py:1888(gca)
#         3    0.000    0.000    0.000    0.000 figure.py:1934(sca)
#         1    0.000    0.000    0.000    0.000 figure.py:1941(_gci)
#         7    0.000    0.000    0.000    0.000 figure.py:199(update)
#         1    0.000    0.000    0.000    0.000 figure.py:2034(add_axobserver)
#         1    0.000    0.000    0.367    0.367 figure.py:2038(savefig)
#         1    0.002    0.002    0.052    0.052 figure.py:2190(colorbar)
#         1    0.000    0.000    0.000    0.000 figure.py:2214(<dictcomp>)
#        42    0.000    0.000    0.000    0.000 figure.py:235(_update_this)
#         1    0.007    0.007    0.040    0.040 figure.py:275(__init__)
#         5    0.000    0.000    0.000    0.000 figure.py:452(_get_axes)
#       194    0.000    0.000    0.000    0.000 figure.py:462(_get_dpi)
#         2    0.000    0.000    0.001    0.001 figure.py:465(_set_dpi)
#         2    0.000    0.000    0.000    0.000 figure.py:482(get_tight_layout)
#         1    0.002    0.002    0.002    0.002 figure.py:486(set_tight_layout)
#       501    0.000    0.000    0.001    0.000 figure.py:49(_stale_figure_callback)
#         5    0.000    0.000    0.000    0.000 figure.py:504(get_constrained_layout)
#         1    0.000    0.000    0.000    0.000 figure.py:512(set_constrained_layout)
#         1    0.000    0.000    0.000    0.000 figure.py:543(set_constrained_layout_pads)
#         2    0.000    0.000    0.000    0.000 figure.py:652(get_children)
#         1    0.000    0.000    0.000    0.000 figure.py:70(__init__)
#         7    0.000    0.000    0.000    0.000 figure.py:74(as_list)
#         3    0.000    0.000    0.001    0.000 figure.py:779(set_canvas)
#         7    0.000    0.000    0.000    0.000 figure.py:78(<listcomp>)
#         7    0.000    0.000    0.000    0.000 figure.py:80(<listcomp>)
#         4    0.000    0.000    0.000    0.000 figure.py:82(get)
#         2    0.000    0.000    0.000    0.000 figure.py:875(set_size_inches)
#         6    0.000    0.000    0.000    0.000 figure.py:898(<genexpr>)
#         6    0.000    0.000    0.000    0.000 figure.py:915(get_size_inches)
#         1    0.000    0.000    0.000    0.000 figure.py:930(get_edgecolor)
#         1    0.000    0.000    0.000    0.000 figure.py:934(get_facecolor)
#         2    0.000    0.000    0.000    0.000 figure.py:958(set_edgecolor)
#         2    0.000    0.000    0.000    0.000 figure.py:968(set_facecolor)
#        99    0.000    0.000    0.000    0.000 font_manager.py:1043(get_default_size)
#       100    0.001    0.000    0.003    0.000 font_manager.py:1179(findfont)
#       600    0.000    0.000    0.001    0.000 font_manager.py:1233(<genexpr>)
#       100    0.000    0.000    0.000    0.000 font_manager.py:1338(get_font)
#       162    0.001    0.000    0.013    0.000 font_manager.py:620(__init__)
#       440    0.001    0.000    0.002    0.000 font_manager.py:660(__hash__)
#       100    0.000    0.000    0.001    0.000 font_manager.py:670(__eq__)
#       440    0.000    0.000    0.000    0.000 font_manager.py:676(get_family)
#       440    0.000    0.000    0.000    0.000 font_manager.py:688(get_style)
#       440    0.000    0.000    0.000    0.000 font_manager.py:695(get_variant)
#       440    0.000    0.000    0.000    0.000 font_manager.py:701(get_weight)
#       440    0.000    0.000    0.000    0.000 font_manager.py:710(get_stretch)
#       572    0.000    0.000    0.000    0.000 font_manager.py:724(get_size_in_points)
#       440    0.000    0.000    0.000    0.000 font_manager.py:727(get_file)
#       162    0.000    0.000    0.000    0.000 font_manager.py:744(set_family)
#       162    0.000    0.000    0.001    0.000 font_manager.py:757(set_style)
#       162    0.000    0.000    0.000    0.000 font_manager.py:767(set_variant)
#       163    0.003    0.000    0.003    0.000 font_manager.py:776(set_weight)
#       162    0.002    0.000    0.002    0.000 font_manager.py:794(set_stretch)
#       190    0.004    0.000    0.004    0.000 font_manager.py:812(set_size)
#       162    0.000    0.000    0.000    0.000 font_manager.py:837(set_file)
#        38    0.000    0.000    0.001    0.000 font_manager.py:858(copy)
#       324    0.000    0.000    0.000    0.000 font_manager.py:928(_normalize_font_family)
#        28    0.000    0.000    0.000    0.000 fromnumeric.py:1755(_nonzero_dispatcher)
# ...
#       154    0.000    0.000    0.001    0.000 transforms.py:2375(transform_non_affine)
#         8    0.000    0.000    0.000    0.000 transforms.py:2385(transform_path_non_affine)
#   222/168    0.001    0.000    0.005    0.000 transforms.py:2395(get_affine)
#         4    0.000    0.000    0.000    0.000 transforms.py:2415(__init__)
#         4    0.000    0.000    0.000    0.000 transforms.py:2459(get_matrix)
#       231    0.000    0.000    0.004    0.000 transforms.py:2470(composite_transform_factory)
#        39    0.000    0.000    0.000    0.000 transforms.py:2553(__init__)
#   111/110    0.000    0.000    0.000    0.000 transforms.py:2573(get_matrix)
#         2    0.000    0.000    0.000    0.000 transforms.py:2616(__init__)
#        24    0.000    0.000    0.000    0.000 transforms.py:2632(get_matrix)
#       117    0.000    0.000    0.001    0.000 transforms.py:2654(__init__)
#       146    0.000    0.000    0.000    0.000 transforms.py:2668(get_matrix)
#        44    0.000    0.000    0.000    0.000 transforms.py:2694(__init__)
#        44    0.000    0.000    0.001    0.000 transforms.py:2710(_revalidate)
#        44    0.000    0.000    0.001    0.000 transforms.py:2722(get_transformed_points_and_affine)
#        44    0.000    0.000    0.000    0.000 transforms.py:2749(get_affine)
#        14    0.000    0.000    0.002    0.000 transforms.py:276(frozen)
#        45    0.001    0.000    0.001    0.000 transforms.py:2791(nonsingular)
#         8    0.000    0.000    0.001    0.000 transforms.py:280(__array__)
#        88    0.000    0.000    0.000    0.000 transforms.py:2867(_interval_contains_close)
#         8    0.000    0.000    0.000    0.000 transforms.py:287(x0)
#        12    0.000    0.000    0.000    0.000 transforms.py:297(y0)
#         2    0.000    0.000    0.000    0.000 transforms.py:307(x1)
#         6    0.000    0.000    0.000    0.000 transforms.py:337(p1)
#        78    0.000    0.000    0.001    0.000 transforms.py:347(xmin)
#        92    0.000    0.000    0.001    0.000 transforms.py:352(ymin)
#        78    0.000    0.000    0.001    0.000 transforms.py:357(xmax)
#        94    0.000    0.000    0.001    0.000 transforms.py:362(ymax)
#        63    0.000    0.000    0.000    0.000 transforms.py:377(intervalx)
#        89    0.000    0.000    0.000    0.000 transforms.py:386(intervaly)
#         6    0.000    0.000    0.000    0.000 transforms.py:395(width)
#         6    0.000    0.000    0.000    0.000 transforms.py:401(height)
#         4    0.000    0.000    0.000    0.000 transforms.py:407(size)
#     28/27    0.000    0.000    0.001    0.000 transforms.py:413(bounds)
#         3    0.000    0.000    0.000    0.000 transforms.py:419(extents)
#         4    0.000    0.000    0.000    0.000 transforms.py:534(anchored)
#         4    0.000    0.000    0.000    0.000 transforms.py:581(shrunk_to_aspect)
#        90    0.001    0.000    0.002    0.000 transforms.py:671(translated)
#        14    0.000    0.000    0.004    0.000 transforms.py:697(union)
#        14    0.000    0.000    0.001    0.000 transforms.py:702(<listcomp>)
#        14    0.000    0.000    0.001    0.000 transforms.py:703(<listcomp>)
#        14    0.000    0.000    0.001    0.000 transforms.py:704(<listcomp>)
#        14    0.000    0.000    0.001    0.000 transforms.py:705(<listcomp>)
#         2    0.000    0.000    0.001    0.000 transforms.py:708(intersection)
#       254    0.001    0.000    0.006    0.000 transforms.py:726(__init__)
#        35    0.000    0.000    0.001    0.000 transforms.py:762(unit)
#         2    0.000    0.000    0.000    0.000 transforms.py:770(null)
#        37    0.000    0.000    0.001    0.000 transforms.py:778(from_bounds)
#        79    0.000    0.000    0.002    0.000 transforms.py:788(from_extents)
#      1693    0.007    0.000    0.007    0.000 transforms.py:82(__init__)
#         4    0.000    0.000    0.000    0.000 transforms.py:824(update_from_path)
#         4    0.000    0.000    0.000    0.000 transforms.py:860(update_from_data_xy)
#         2    0.000    0.000    0.000    0.000 transforms.py:911(p1)
#         7    0.000    0.000    0.000    0.000 transforms.py:916(intervalx)
#         9    0.000    0.000    0.000    0.000 transforms.py:921(intervaly)
#         6    0.000    0.000    0.000    0.000 transforms.py:938(minposx)
#         8    0.000    0.000    0.000    0.000 transforms.py:942(minposy)
#       569    0.000    0.000    0.000    0.000 transforms.py:946(get_points)
#        10    0.000    0.000    0.001    0.000 transforms.py:964(set)
#        39    0.000    0.000    0.000    0.000 transforms.py:994(__init__)
#        64    0.000    0.000    0.000    0.000 units.py:122(is_numlike)
#     30/16    0.000    0.000    0.001    0.000 units.py:142(get_converter)
#         1    0.000    0.000    0.000    0.000 warnings.py:106(_formatwarnmsg)
#         1    0.001    0.001    0.006    0.006 warnings.py:20(_showwarnmsg_impl)
#         1    0.000    0.000    0.000    0.000 warnings.py:35(_formatwarnmsg_impl)
#         1    0.000    0.000    0.000    0.000 warnings.py:408(__init__)
#         1    0.001    0.001    0.007    0.007 warnings.py:85(_showwarnmsg)
#        12    0.000    0.000    0.000    0.000 weakref.py:44(__new__)
#         2    0.001    0.000    0.001    0.001 weakref.py:51(_cb)
#         1    0.000    0.000    0.000    0.000 weakref.py:73(__eq__)
#         2    0.000    0.000    0.000    0.000 widgets.py:33(__init__)
#       492    0.002    0.000    0.002    0.000 {built-in method __new__ of type object at 0x102a8d6a8}
#       560    0.002    0.000    0.002    0.000 {built-in method _abc._abc_instancecheck}
#        44    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         3    0.000    0.000    0.002    0.001 {built-in method _functools.reduce}
#         4    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.004    0.004    0.011    0.011 {built-in method _warnings.warn}
#      4348    0.079    0.000    0.079    0.000 {built-in method builtins.abs}
#       118    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        63    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       205    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#        56    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.004    0.004    2.063    2.063 {built-in method builtins.exec}
#      4971    0.002    0.000    0.003    0.000 {built-in method builtins.getattr}
#      4959    0.002    0.000    0.002    0.000 {built-in method builtins.hasattr}
#   923/582    0.000    0.000    0.002    0.000 {built-in method builtins.hash}
#      1488    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#     10494    0.003    0.000    0.005    0.000 {built-in method builtins.isinstance}
#        65    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       534    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#      2047    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       285    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#        45    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#      1420    0.001    0.000    0.010    0.000 {built-in method builtins.next}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#      1292    0.000    0.000    0.001    0.000 {built-in method builtins.setattr}
#       358    0.002    0.000    0.002    0.000 {built-in method builtins.sorted}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        76    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#         4    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#        50    0.000    0.000    0.000    0.000 {built-in method math.cos}
#        48    0.000    0.000    0.000    0.000 {built-in method math.floor}
#        76    0.000    0.000    0.000    0.000 {built-in method math.log10}
#       100    0.000    0.000    0.000    0.000 {built-in method math.radians}
#        50    0.000    0.000    0.000    0.000 {built-in method math.sin}
#         4    0.050    0.012    0.050    0.013 {built-in method matplotlib._image.resample}
#       271    0.001    0.000    0.001    0.000 {built-in method matplotlib._path.affine_transform}
#         8    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.get_path_extents}
#         4    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.update_path_extents}
#         1    0.086    0.086    0.086    0.086 {built-in method matplotlib._png.write_png}
#        34    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#      3564    0.111    0.000    0.112    0.000 {built-in method numpy.array}
# 2449/1971    0.010    0.000    0.062    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        35    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         8    0.002    0.000    0.002    0.000 {built-in method numpy.empty}
#        58    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        29    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        13    0.001    0.000    0.001    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#      7626    0.002    0.000    0.002    0.000 {function RcParams.__getitem__ at 0x109def378}
#         3    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        16    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#         7    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         4    0.003    0.001    0.003    0.001 {method 'any' of 'numpy.generic' objects}
#        11    0.000    0.000    0.002    0.000 {method 'any' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       924    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.generic' objects}
#       113    0.005    0.000    0.005    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.001    0.001 {method 'clear' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       100    0.000    0.000    0.000    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#        31    0.000    0.000    0.007    0.000 {method 'clip' of 'numpy.ndarray' objects}
#        19    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.generic' objects}
#       589    0.004    0.000    0.004    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       298    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        50    0.002    0.000    0.002    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#         2    0.003    0.002    0.004    0.002 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        44    0.003    0.000    0.003    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        16    0.005    0.000    0.005    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         2    0.000    0.000    0.001    0.000 {method 'draw_quad_mesh' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        50    0.003    0.000    0.003    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         2    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        22    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       401    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        50    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#       100    0.000    0.000    0.000    0.000 {method 'get_descent' of 'matplotlib.ft2font.FT2Font' objects}
#        50    0.000    0.000    0.000    0.000 {method 'get_width_height' of 'matplotlib.ft2font.FT2Font' objects}
#         4    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.generic' objects}
#       277    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#      6124    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      1228    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       389    0.002    0.000    0.002    0.000 {method 'match' of 're.Pattern' objects}
#       153    0.000    0.000    0.031    0.000 {method 'max' of 'numpy.ndarray' objects}
#        89    0.000    0.000    0.032    0.000 {method 'min' of 'numpy.ndarray' objects}
#        28    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#       111    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#      6978    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#       185    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1161    0.068    0.000    0.068    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        14    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#       169    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#       292    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 {method 'round' of 'numpy.generic' objects}
#        64    0.000    0.000    0.000    0.000 {method 'round' of 'numpy.ndarray' objects}
#         8    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#       100    0.012    0.000    0.012    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#        29    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        25    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#      1712    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        28    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         3    0.010    0.003    0.010    0.003 {method 'take' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       786    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#       744    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#     78/72    0.000    0.000    0.001    0.000 {method 'view' of 'numpy.generic' objects}
#   143/139    0.000    0.000    0.002    0.000 {method 'view' of 'numpy.ndarray' objects}
#      4091    0.261    0.000    0.261    0.000 {mkl_fft._pydfti.fft}

# %% [markdown]
# ## cProfile parts of code
# ### * Wrap the following markdowns as $\mathbf{def}\:\:\: \mathit{plot\_specgram(\dots)}\:\:\: \:\:\: $ and as $\:\:\: \:\:\: \mathbf{def}\:\:\: \mathit{compute\_specgram(\dots)}$: ![Image_1.png](Image_1.png)
# ![Image_3.png](Image_3.png)
#
# ### * Use, for example, $\mathit{time()}$ for your own profiling, by using, e.g., $\mathit{from\: time\: import\: time}$.
# ### * Vary $\operatorname{n\_timestamps\_given}$ and (by using, e.g., $\mathit{time()}$) calulate computational time expended on $\mathit{plot\_specgram(\dots)}$ ($=t_{plot}(nwindowsteps\_given)$) and $\mathit{compute\_specgram(\dots)}$ ($=t_{compute}(nwindowsteps\_given)$) and ratios $\frac{t_{plot}(nwindowsteps\_given)}{t_{total}(n\_timestamps\_given)}$ $\frac{t_{compute}(nwindowsteps\_given)}{t_{total}(nwindowsteps\_given)}$, where $t_{total}(nwindowsteps\_given)$ is total computational time of program in for each $n\_timestamps\_given$
# ### * Plot the graphs of the ratios versus $\mathit{nwindowsteps\_given}$, label axises and title.
