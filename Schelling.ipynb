# %%
import random
import numpy as np
from tqdm.auto import tqdm
from ipywidgets import interact, interactive
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %reload_ext autoreload
# %autoreload 2
# Wider cells
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

import os
os.mkdir('imgs/')
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Task 3: Schelling model

# %% [markdown]
# ## T3.1	9 gifs for 9 values of R

# %%
from schelling import game_2d
# %matplotlib inline
R = [0, 1/8, 1/4, 3/8, 1/2, 5/8, 3/4, 7/8, 1]

N = 50
C = 2
game_length = 50
global_moved = []
for r in R:
    moved = game_2d(N, C, r, game_length, name=f'schelling_{int(r*8)}', figsize=(6, 6))
    global_moved.append(moved)
# Out:
# HBox(children=(IntProgress(value=0, description='Number of neighbours=0', max=50, style=ProgressStyle(descript…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=1', max=50, style=ProgressStyle(descript…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=2', max=50, style=ProgressStyle(descript…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=3', max=50, style=ProgressStyle(descript…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=4', max=50, style=ProgressStyle(descript…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=5', max=50, style=ProgressStyle(descript…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=6', max=50, style=ProgressStyle(descript…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=7', max=50, style=ProgressStyle(descript…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=8', max=50, style=ProgressStyle(descript…

# %% [markdown]
# ![schelling_0](imgs/schelling_0.gif)
# ![schelling_1](imgs/schelling_1.gif)
# ![schelling_2](imgs/schelling_2.gif)
# ![schelling_3](imgs/schelling_3.gif)
# ![schelling_4](imgs/schelling_4.gif)
# ![schelling_5](imgs/schelling_5.gif)
# ![schelling_6](imgs/schelling_6.gif)
# ![schelling_7](imgs/schelling_7.gif)
# ![schelling_8](imgs/schelling_8.gif)

# %% [markdown]
# #### 2D model with C=3

# %%
from schelling import game_2d
# %matplotlib inline
R = [0, 1/8, 1/4, 3/8, 1/2, 5/8, 3/4, 7/8, 1]

N = 100
C = 3
game_length = 100
global_moved_3 = []
for r in R:
    moved = game_2d(N, C, r, game_length, name=f'schelling_{C}_{int(r*8)}', figsize=(10, 10))
    global_moved_3.append(moved)
# Out:
# HBox(children=(IntProgress(value=0, description='Number of neighbours=0', style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=1', style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=2', style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=3', style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=4', style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=5', style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=6', style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=7', style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=8', style=ProgressStyle(description_widt…

# %%
![schelling_2_1](imgs/schelling_3_2.gif)
![schelling_2_1](imgs/schelling_3_3.gif)
![schelling_2_1](imgs/schelling_3_4.gif)
![schelling_2_1](imgs/schelling_3_5.gif)
![schelling_2_1](imgs/schelling_3_6.gif)
![schelling_2_1](imgs/schelling_3_7.gif)

# %% [markdown]
# #### 2D model with C=10

# %%
from schelling import game_2d
# %matplotlib inline
R = [0, 1/8, 1/4, 3/8, 1/2, 5/8, 3/4, 7/8, 1]

N = 100
C = 10
game_length = 200
global_moved_10 = []
for r in R:
    moved = game_2d(N, C, r, game_length, name=f'schelling_{C}_{int(r*8)}', figsize=(10, 10))
    global_moved_10.append(moved)
# Out:
# HBox(children=(IntProgress(value=0, description='Number of neighbours=0', max=200, style=ProgressStyle(descrip…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=1', max=200, style=ProgressStyle(descrip…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=2', max=200, style=ProgressStyle(descrip…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=3', max=200, style=ProgressStyle(descrip…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=4', max=200, style=ProgressStyle(descrip…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=5', max=200, style=ProgressStyle(descrip…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=6', max=200, style=ProgressStyle(descrip…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=7', max=200, style=ProgressStyle(descrip…
# HBox(children=(IntProgress(value=0, description='Number of neighbours=8', max=200, style=ProgressStyle(descrip…

# %%
N = 1000
C = 10
game_length = 250
r = R[3]
_ = game_2d(N, C, r, game_length, name=f'schelling_{C}_{int(r*8)}_big', figsize=(10, 10))
# Out:
# HBox(children=(IntProgress(value=0, description='Number of neighbours=3', max=250, style=ProgressStyle(descrip…

# %% [markdown]
# ![schelling_3_1](imgs/schelling_10_3.gif)
# ![schelling_3_1_big](imgs/schelling_10_3_big.gif)

# %% [markdown]
# ## T3.2 Plot

# %%
fig, ax = plt.subplots(figsize=(14,11))
# fig.figure(figsize=(14,11))
for i, r in enumerate(R):
    ax.plot(global_moved[i], label=f'R={int(r*8)}|8')
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.set_xlabel('iteration', fontsize=20)
    ax.set_ylabel('# of moves', fontsize=20)
    ax.legend(fontsize=20)
# plt.plot(global_moved[0], label='r')

# %%
fig, ax = plt.subplots(figsize=(14,11))
# fig.figure(figsize=(14,11))
for i, r in enumerate(R):
    ax.plot(global_moved_3[i], label=f'R={int(r*8)}|8')
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.set_xlabel('iteration', fontsize=20)
    ax.set_ylabel('# of moves', fontsize=20)
    ax.legend(fontsize=20)
# plt.plot(global_moved[0], label='r')

# %%
fig, ax = plt.subplots(figsize=(14,11))
for i, r in enumerate(R):
    ax.plot(global_moved_10[i], label=f'R={int(r*8)}|8')
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.set_xlabel('iteration', fontsize=20)
    ax.set_ylabel('# of moves', fontsize=20)
    ax.legend(fontsize=20)
# plt.plot(global_moved[0], label='r')

# %%
fig, ax = plt.subplots(figsize=(14,11))
ax.plot(_, label=f'R={int(r*8)}|8')
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xlabel('iteration', fontsize=20)
ax.set_ylabel('# of moves', fontsize=20)
ax.legend(fontsize=20)

# %% [markdown]
# ## T3.3 Bonus: 3D Schelling model

# %% [markdown]
# ### Check that everything works correctly
# Plot 3D cube and projections on each plane for one class (here I chosen to project class 1), so color defines total number of 'ones' in that plane cell

# %%
from tqdm.auto import tqdm
from schelling_3d import init_map_3d, prepare_3d_plot, plot_3d, plot_projections
# %matplotlib inline
# %matplotlib notebook
R = [0, 1/8, 1/4, 3/8, 1/2, 5/8, 3/4, 7/8, 1]
N = 15
C = 2 # Number of different neighbourhoods
r = R[5]
game_map = init_map_3d(N,C)
x, y, z, c, proj_x, proj_y, proj_z = prepare_3d_plot(game_map, projections=True)
# Plot 3D cube to check 
plot_3d(x, y, z, c, r, figsize=(8, 8))
# Plot projections
plot_projections(proj_x, proj_y, proj_z)

# %% [markdown]
# If we increase N size of cube becomes to big to visialize it properly, some projections are more reliable. ALso notice, that in the beginnig cells are almost evenly distributed.

# %%
# %matplotlib inline
from schelling_3d import plot_3d
R = [0, 1/8, 1/4, 3/8, 1/2, 5/8, 3/4, 7/8, 1]
N = 50
C = 2 # Number of different neighbourhoods
game_map = init_map_3d(N,C)
x, y, z, c, proj_x, proj_y, proj_z = prepare_3d_plot(game_map, projections=True)
plot_3d(x, y, z, c, r, figsize=(14, 14))
plot_projections(proj_x, proj_y, proj_z)

# %% [markdown]
# Now let's start the 3D game and see, how distrubutions are changing

# %%
from tqdm.auto import tqdm
from schelling_3d import game_3d
# %matplotlib inline

N = 15
C = 2 # Number of different neighbourhoods
game_length = 80
projective=False
r = R[6]
fname=f'schelling_{projective}_{int(r*8)}_{N}_{game_length}'
final_map, moved = game_3d(N, C, r, game_length, name=fname, proj=projective, figsize=(6, 6), fps=8, verbouse=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Number of neighbours=20', max=80, style=ProgressStyle(descrip…

# %% [markdown]
# Let's look at the number of moving cells

# %%
fig, ax = plt.subplots()
# fig.figure(figsize=(14,11))
ax.plot(moved, label=f'R={int(r*27)}|27')
ax.set_xlabel('iteration')
ax.set_ylabel('# of moves')
ax.legend()
plt.savefig(f'imgs/{fname}.png')

# %% [markdown]
# ### Generate GIFs for different R values
# #### First: Find values of R, when something interesting happens.

# %%
from tqdm.auto import tqdm
from schelling_3d import game_3d
# %matplotlib inline
R_3d = [i / 27 for i in range(27)]
N = 10
C = 2 # Number of different neighbourhoods
game_length = 20
projective=True

global_moved = []
for r in R_3d:
    fname=f'tmp/schelling_{projective}_{int(r*27)}_{N}_{game_length}'
    _, moved = game_3d(N, C, r, game_length, name=fname, proj=projective, figsize=(6, 6), fps=8, verbouse=False)
    global_moved.append(moved)

# %%
fig, ax = plt.subplots(figsize=(15, 15))
# fig.figure(figsize=(14,11))
for i, r in enumerate(R_3d):
    ax.plot(global_moved[i], label=f'R={int(r*27)}|27')
    ax.set_xlabel('iteration', fontsize=20)
    ax.set_ylabel('# of moves')
    ax.legend()
# plt.plot(global_moved[0], label='r')

# %% [markdown]
# #### Let's take $R = 15$ and look how far will it get

# %%
from tqdm.auto import tqdm
from schelling_3d import game_3d
# %matplotlib inline
N = 100
C = 2 # Number of different neighbourhoods
game_length = 100
projective=True
r = R_3d[15]
fname=f'schelling_{projective}_{int(r*27)}_{N}_{game_length}'
_, moved_15 = game_3d(N, C, r, game_length, name=fname, proj=projective, figsize=(6, 6), fps=8, verbouse=False)
# Out:
# HBox(children=(IntProgress(value=0, description='Number of neighbours=15', style=ProgressStyle(description_wid…

# %% [markdown]
# Launch this cell to see gif:
# ![schelling_3d_15](imgs/schelling_True_15_100_100.gif)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(moved_15, label=f'R={int(r*8)}|8')
ax.set_xlabel('iteration', fontsize=20)
ax.set_ylabel('# of moves', fontsize=20)
ax.legend(fontsize=20)
plt.savefig(f'imgs/{fname}.png')

# %% [markdown]
# Select R = 14 and wait VERY long.
# Set verbouse=True to get initial and final distributions of cells.

# %%
from tqdm.auto import tqdm
from schelling_3d import game_3d
# %matplotlib inline
N = 80
C = 2 # Number of different neighbourhoods
game_length = 200
projective=True
r = R_3d[14]
fname=f'schelling_{projective}_{int(r*27)}_{N}_{game_length}'
final_map, moved_14 = game_3d(N, C, r, game_length, name=fname, proj=projective, figsize=(6, 6), fps=8, verbouse=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Number of neighbours=14', max=1000, style=ProgressStyle(descr…

# %% [markdown]
# Let's generate GIF for 3D cube

# %%
from tqdm.auto import tqdm
from schelling_3d import game_3d
# %matplotlib inline
N = 20
C = 2 # Number of different neighbourhoods
game_length = 1000
projective=False
r = R_3d[14]
fname=f'schelling_{projective}_{int(r*27)}_{N}_{game_length}'
final_map, moved_14 = game_3d(N, C, r, game_length, name=fname, proj=projective, figsize=(6, 6), fps=10, verbouse=False)
# Out:
# HBox(children=(IntProgress(value=0, description='Number of neighbours=14', max=1000, style=ProgressStyle(descr…

# %%
x, y, z, c, proj_x, proj_y, proj_z = prepare_3d_plot(final_map, projections=True)
plot_3d(x, y, z, c, r, figsize=(14, 14))
# plot_projections(proj_x, proj_y, proj_z)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(moved_14[100:], label=f'R={int(r*8)}|8')
ax.set_xlabel('iteration', fontsize=20)
ax.set_ylabel('# of moves', fontsize=20)
ax.legend(fontsize=20)
plt.savefig(f'imgs/{fname}.png')
