# %%
#Bifurcation map

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline
import numpy as np
from random import random

# %%
n = 200 
m = 200
x_i = random()
r = 3.4
x_n = []
def map_fun(r, x):
    return r*x*(1-x)

for i in range (n+m):
    x_i = map_fun(r, x_i)
    if i > n:
        x_n.append(x_i)
        
plt.figure(figsize=(14, 11))
plt.suptitle('Evolution of x for r = {}'.format(r), fontsize = 20)
plt.xlabel('Iterations after n = {}'.format(n), fontsize = 20)
plt.ylabel('x_n', fontsize = 20)
plt.plot(x_n, '.')

# %%
x_i = random()  #initial value of x
n = 200  #number of iterations
last = 200  #number of last values that we take into account
r_values = np.linspace(0, 4, 500)

res = []
for r in r_values:
    x_n = []
    x_i = random()
    for i in range(n+last):
        x_i = map_fun(r, x_i)
        if i >= n:
            x_n.append(x_i) 


    res.append(x_n)

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('r', fontsize = 20)
plt.ylabel('x_n', fontsize = 20)
_ = plt.plot(r_values, res, 'g.', markersize = 0.1)

# %%
timeit_arr = []
for i in range(1, 11):
    timeit_value = %timeit -o ! mpiexec mpirun -n {i} python B.py
#    timeit_arr.append(sum(timeit_value.all_runs)/len(timeit_value.all_runs))
    timeit_arr.append(timeit_value.average)
# Out:
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# 2.48 s ± 52.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# 2.12 s ± 74.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# 2.69 s ± 138 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# 2.91 s ± 75.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# 3.37 s ± 21.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# 4.02 s ± 152 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# 5.14 s ± 822 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 4.81 s ± 381 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.26 s ± 395 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.72 s ± 578 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
plt.figure(figsize=(14, 11))
num_of_processes = np.linspace(1, len(timeit_arr), len(timeit_arr))
plt.xlabel('number of processes', fontsize = 20)
plt.ylabel('Speedup = t1/tn', fontsize = 20)
plt.suptitle('Speedup in depend on num of processes', fontsize = 20)

t1 = timeit_arr[0]
def SpeedUp(tn):
    return t1/tn
Speedup = list(map(SpeedUp, timeit_arr))
plt.plot(num_of_processes, Speedup)


#Speedup = t1/tn
