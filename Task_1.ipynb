# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

from ipywidgets import interact, interactive

# Wider cells
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

# Make interactive cells
from ipywidgets import interact, interactive

# Make sure folder for images exist
import os
try:
    os.mkdir('img/task1')
except FileExistsError as err:
    pass

# Jupyter magic
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # T1.1 Implement the map, plot the evolution of x

# %%
## Evolution
def bifurcation(x, r):
    return r * x * (1 - x)

@interact(r = 3.3,n=2, m=20)
def evolution(r, n, m):
    res = []
    x = np.random.random()
    for _ in range(n):
        x = bifurcation(x, r)
    for _ in range(m):
        x = bifurcation(x, r)
        res.append(x)
    plt.plot(res)

# %% [markdown]
# # T1.2	Create a linspace of r’s, for every r save the last “m” values of x after the first “n” values, play around with values
#
# # T1.3 Get the bifurcation map

# %%
from code.bifurcation import bifurcation_map, plot_bifurcation
r = 4 # max number of R
n = 1000 # iterate for n values
steps = 100 # divide interval from 0 to R into steps
m = 100 # save last m values 

r_values, bf = bifurcation_map(R=r, steps=steps, n=n, m=m)
plot_bifurcation(r_values, bf, name="bifurcation_v1", params=[n, m, r], save_fig=True)
